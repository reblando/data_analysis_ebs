# %%
import re
import codecs
import glob
import csv
import pandas as pd
import numpy as np
import pickle
# %autosave 5
# Out:
# Autosaving every 5 seconds

# %% [markdown]
# # Constructing Standard Data Files for Online Participants
# ##### 5/27/20
# ## I. Treating Log Files
# ### A. Reading in Log Files

# %%
#pilot1
files1 = glob.glob("/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot1/7/*.log")

#pilot2
files2 = glob.glob("/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/*.log")

#pilot3
files3 = glob.glob("/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot3/4/*.log")

#pilot4
files4 = glob.glob("/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot4/7/*.log")

#final ver- p
filesp = glob.glob("/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/finalver_p/10/*.log")

#final ver- b1
filesb1 = glob.glob("/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/finalver_b1/33/*.log")

#final ver- b2
filesb2 = glob.glob("/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/finalver_b2/30/*.log")

# %% [markdown]
# ### (Adjust here which groups to include in analysis)

# %%
files = files2
# we'll use a regex for this even though they're ugly and painful:
scanQuote = re.compile(r"'(.*?)'")  # finds any number of words within a quote
print(len(files))
# Out:
# 8

# %% [markdown]
# ### B. Import Qualtrics CSV

# %%
q_df = pd.read_csv("qualtrics/qualtrics.csv")

# %% [markdown]
# ### C. Import CSVs

# %%
#FullForce Behavioral

#pilot1
csv1 = glob.glob("/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot1/7/*.csv")

#pilot2
csv2 = glob.glob("/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/*.csv")

#pilot3
csv3 = glob.glob("/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot3/4/*.csv")

#pilot4
csv4 = glob.glob("/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot4/7/*.csv")

#final ver- p
csvp = glob.glob("/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/finalver_p/10/*.csv")

#final ver- b1
csvb1 = glob.glob("/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/finalver_b1/33/*.csv")

#final ver- b2
csvb2 = glob.glob("/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/finalver_b2/30/*.csv")

# %% [markdown]
# ### (Insert here which files to include)

# %%
csvnames = csv2


csv_df = {}

for csvname in csvnames:
    print(csvname)
    label = csvname[:-4]
    
    csv_df[label] = pd.read_csv(csvname)
    
print('done!')
# Out:
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_12h52.50.131.csv
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_20h42.51.597.csv
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_20h43.08.493.csv
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-12_19h57.55.241.csv
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_15h04.13.258.csv
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h16.09.618.csv
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h17.04.991.csv
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h18.58.644.csv
# done!

# %% [markdown]
# ### B. Creating dictionary files_pd with log files data filtered (key: filename .log)

# %%
#instantiate dictionary
files_pd = {}

for filename in files:
    print(filename)
    # open log file
    thisFile = codecs.open( filename, 'r', 'utf-8')
    #initiate a dataframe
    df = pd.DataFrame(columns=['time','keypress'])
    #go through each line in the file
    for line in thisFile.readlines():
        if "DATA" in line:  # new trial reset all entries
            if "Keydown:" in line:
                first, keypress = line.split("Keydown:")
                time = first.split("\t")[0]
                keypress = keypress.strip()
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
            else:
                pass
        if "text_34: autoDraw = false" in line:
            time = "here"
            keypress = 33
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        #recording the distractor words    
        if "text_66: text =" in line:
            time = 'distractor_text'
            b, keypress = line.split("text = ")
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        #mark the end of the distractor typing
        if "instr_9: autoDraw = false" in line:
            time = 44
            keypress = 0
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        #recording the short answer questions
        if "instr: text =" in line:
            b, keypress = line.split("text = ")
            time = 'Q1'
            keypress = keypress.strip()
            if keypress == "\"default text\"":
                pass
            else:
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "instr_2: text =" in line:
            b, keypress = line.split("text = ")
            time = 'Q2'
            keypress = keypress.strip()
            if keypress == "\"default text\"":
                pass
            else:
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "instr_3: text =" in line:
            b, keypress = line.split("text = ")
            time = 'Q3'
            keypress = keypress.strip()
            if keypress == "\"default text\"":
                pass
            else:
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "instr_4: text =" in line:
            b, keypress = line.split("text = ")
            time = 'Q4'
            keypress = keypress.strip()
            if keypress == "\"default text\"":
                pass
            else:
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "instr_5: text =" in line:
            b, keypress = line.split("text = ")
            time = 'Q5'
            keypress = keypress.strip()
            if keypress == "\"default text\"":
                pass
            else:
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "instr_6: text =" in line:
            b, keypress = line.split("text = ")
            time = 'Q6'
            keypress = keypress.strip()
            if keypress == "\"default text\"":
                pass
            else:
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "instr_7: text =" in line:
            b, keypress = line.split("text = ")
            time = 'Q7'
            keypress = keypress.strip()
            if keypress == "\"default text\"":
                pass
            else:
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "instr_8: text =" in line:
            b, keypress = line.split("text = ")
            time = 'Q8'
            keypress = keypress.strip()
            if keypress == "\"default text\"":
                pass
            else:
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        #short answers
        text_num = ["43", "44", "45", "46", "47", "48", "51", "53"]
        if "text_43: text = " in line:
            b, keypress = line.split("text = ")
            time = 'A1'
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "text_44: text = " in line:
            b, keypress = line.split("text = ")
            time = 'A2'
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "text_45: text = " in line:
            b, keypress = line.split("text = ")
            time = 'A3'
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "text_46: text = " in line:
            b, keypress = line.split("text = ")
            time = 'A4'
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "text_47: text = " in line:
            b, keypress = line.split("text = ")
            time = 'A5'
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "text_48: text = " in line:
            b, keypress = line.split("text = ")
            time = 'A6'
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "text_51: text = " in line:
            b, keypress = line.split("text = ")
            time = 'A7'
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "text_53: text = " in line:
            b, keypress = line.split("text = ")
            time = 'A8'
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
    #remove rows of pd with empty keypress values
    df = df[df.keypress != '""']
    df = df[df.keypress != '']
    #reset index
    df = df.reset_index(drop=True)
    #add the df to the dictionary
    files_pd[filename] = df
# Out:
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_12h52.50.131.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_20h42.51.597.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_20h43.08.493.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-12_19h57.55.241.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_15h04.13.258.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h16.09.618.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h17.04.991.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h18.58.644.log

# %%
files_pd['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_20h42.51.597.log']
# Out:
#                    time       keypress
# 0    168.35000000000002          Enter
# 1               215.615              9
# 2    219.64600000000002              1
# 3                252.53  AudioVolumeUp
# 4    252.91000000000003  AudioVolumeUp
# ..                  ...            ...
# 391             602.255              m
# 392                  A8       "econom"
# 393             602.437              y
# 394                  A8      "economy"
# 395   602.6039999999999          Enter
#
# [396 rows x 2 columns]

# %% [markdown]
# ## II. Building Standardized Data File
# #### pd w cols = story, type, persp, alt_persp, sa_order, story_presses, distractors, 'SA's
#
# ## A. Instantiate df data_dict (key: filename)

# %%
data_dict = {}

#fill data_dict with all files
for filename in files:
    this_df = pd.DataFrame()
    label = filename[:-4]
    data_dict[label] = this_df

# %%
len(csvnames)
# Out:
# 8

# %% [markdown]
# ## C. Extract information from files_pd
# ### i. story_presses

# %%
#include if statement, since if the values are in the .csv we will use those, maybe not actually. If this method works
#why not make it ubiquitous for all. I will do some comparisons with people who do have story_presses in their .csv
#to verify this extraction method

for filename in files:
    #call the dataframe for this file
    df = files_pd[filename]
    #finding index of 'here'
    here = np.array(df.index[df['time'] == 'here'].tolist())
    #subtracting 1 to get index of keypresses
    seg = here - 1
    #getting the keypress values
    key_vals = df['keypress'][seg].tolist()
    #turning keypresses into ints
    key_vals = [int(i) for i in key_vals]
    #adjusting the filename to match the key
    label = filename[:-4]
    #adding the key_vals to the df
    data_dict[label]['story_presses'] = key_vals

# %% [markdown]
# ### ii. short answers

# %%
Alist = ['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8']

for filename in files:
    df = files_pd[filename]
    for thisA in Alist:
        #finding index of thisA
        here = np.array(df.index[df['time'] == thisA].tolist())
        #getting the keypress values
        key_vals = df['keypress'][here].tolist()
        if not key_vals:
            this_val = ''
        else:
            #index the last value
            this_val = key_vals[-1]
        label = filename[:-4]
        #adding the key_vals to the df
        data_dict[label][thisA] = this_val

# %%
data_dict.keys()
# Out:
# dict_keys(['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_12h52.50.131', '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_20h42.51.597', '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_20h43.08.493', '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-12_19h57.55.241', '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_15h04.13.258', '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h16.09.618', '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h17.04.991', '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h18.58.644'])

# %% [markdown]
# ### iii. distractors

# %%
for filename in files:
    print(filename)
    #get the label for the data_dict
    label = filename[:-4]
    #select df from files_pd
    df = files_pd[filename]
    #finding the index of 44, the marker for distractor texts
    here = np.array(df.index[df['time'] == 44].tolist())
    #subtracting 2 to get index of keypresses
    distractors = here - 2
    distractor_vals = df['keypress'][distractors].tolist()
    for i in range(0, 5):
        data_dict[label]['distractor' + str(i+1)] = distractor_vals[i]
# Out:
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_12h52.50.131.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_20h42.51.597.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_20h43.08.493.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-12_19h57.55.241.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_15h04.13.258.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h16.09.618.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h17.04.991.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h18.58.644.log

# %% [markdown]
# ## D. Extract info from CSV files
# ### i. Get prolific_id, story, type, persp, alt_persp, sa_order

# %%
for filename in files:
    #get the label for the data_dict
    label = filename[:-4]
    #getting prolific id
    data_dict[label]['prolific_id'] = csv_df[label]['Prolific_ID'].iloc[0]
    #getting story number
    data_dict[label]['story'] = int(csv_df[label]['story'].iloc[0])
    #getting priming type
    data_dict[label]['p_type'] = int(csv_df[label]['val2'].iloc[0])
    #perspective
    if "persp_val" in csv_df[label]:
        data_dict[label]['persp'] = int(csv_df[label]['persp_val'].iloc[0])
        #alternative perspective
        data_dict[label]['alt_persp'] = int(csv_df[label]['alt_persp_val'].iloc[0])
    else:
        data_dict[label]['persp'] = int(csv_df[label]['perp_val'].iloc[0])
        #alternative perspective
        data_dict[label]['alt_persp'] = int(csv_df[label]['alt_perp_val'].iloc[0])
    #short answer order
    if "sa_order" in csv_df[label]:
        data_dict[label]['sa_order'] = int(csv_df[label]['sa_order'].iloc[0])
    #if the short answer order is not in the file (pilot i, ii) then put the first sa question in 'sa_order' column    
    else:
        data_dict[label]['sa_order'] = files_pd[filename].loc[files_pd[filename]['time'] == 'Q1', 'keypress'].iloc[0]

# %% [markdown]
# ## E. Recall Data from Qualtrics

# %% [markdown]
# ### ii. Insert Recall Data from Qualtrics CSV into data_dict using prolific_id

# %%
for key in data_dict.keys():
    print(key)
    #getting prolific id from data_dict
    this_id = data_dict[key]['prolific_id'].iloc[0]
    print(this_id)
    this_id_new = this_id.strip()
    print(this_id)
    if this_id in q_df.values:
        #index of row with this_id
        data_dict[key]['recall'] = q_df.loc[q_df['Q1'] == this_id, 'Q8'].iloc[0]
    elif this_id_new in q_df.values:
        data_dict[key]['recall'] = q_df.loc[q_df['Q1'] == this_id_new, 'Q8'].iloc[0]
# Out:
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_12h52.50.131
# 5cf0a300b094d700183e4d54
# 5cf0a300b094d700183e4d54
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_20h42.51.597
# 5ce5b9844cd8130019acba32
# 5ce5b9844cd8130019acba32
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_20h43.08.493
# 597cb71cd4e83700016c35b2
# 597cb71cd4e83700016c35b2
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-12_19h57.55.241
# 5e7b804f9379140478c688da
# 5e7b804f9379140478c688da
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_15h04.13.258
# 5eac5376dfc1010c08a633bb
# 5eac5376dfc1010c08a633bb
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h16.09.618
# 5cea26087afd86001a34a5db
# 5cea26087afd86001a34a5db
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h17.04.991
# 5deae08fe4f84020dfafac72
# 5deae08fe4f84020dfafac72
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h18.58.644
# 5bc9e924e642db0001d3a1c5
# 5bc9e924e642db0001d3a1c5

# %% [markdown]
# ## F. Pickling

# %%
pickle.dump( data_dict, open( "pickle/data_dict_b1.p", "wb" ) )

# %%
data_dict.keys()
# Out:
# dict_keys(['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_12h52.50.131', '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_20h42.51.597', '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_20h43.08.493', '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-12_19h57.55.241', '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_15h04.13.258', '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h16.09.618', '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h17.04.991', '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h18.58.644'])

# %%
data_dict['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_20h42.51.597']
# Out:
#     story_presses     distractor1        distractor2    distractor3  \
# 0               1  "accroutments"  "tintinnabultion"  "hippocampus"
# 1               1  "accroutments"  "tintinnabultion"  "hippocampus"
# 2               9  "accroutments"  "tintinnabultion"  "hippocampus"
# 3               9  "accroutments"  "tintinnabultion"  "hippocampus"
# 4               9  "accroutments"  "tintinnabultion"  "hippocampus"
# 5               1  "accroutments"  "tintinnabultion"  "hippocampus"
# 6               1  "accroutments"  "tintinnabultion"  "hippocampus"
# 7               9  "accroutments"  "tintinnabultion"  "hippocampus"
# 8               9  "accroutments"  "tintinnabultion"  "hippocampus"
# 9               1  "accroutments"  "tintinnabultion"  "hippocampus"
# 10              1  "accroutments"  "tintinnabultion"  "hippocampus"
# 11              9  "accroutments"  "tintinnabultion"  "hippocampus"
# 12              9  "accroutments"  "tintinnabultion"  "hippocampus"
# 13              1  "accroutments"  "tintinnabultion"  "hippocampus"
# 14              1  "accroutments"  "tintinnabultion"  "hippocampus"
# 15              1  "accroutments"  "tintinnabultion"  "hippocampus"
# 16              1  "accroutments"  "tintinnabultion"  "hippocampus"
# 17              1  "accroutments"  "tintinnabultion"  "hippocampus"
# 18              9  "accroutments"  "tintinnabultion"  "hippocampus"
# 19              9  "accroutments"  "tintinnabultion"  "hippocampus"
# 20              9  "accroutments"  "tintinnabultion"  "hippocampus"
# 21              9  "accroutments"  "tintinnabultion"  "hippocampus"
# 22              9  "accroutments"  "tintinnabultion"  "hippocampus"
# 23              1  "accroutments"  "tintinnabultion"  "hippocampus"
# 24              9  "accroutments"  "tintinnabultion"  "hippocampus"
# 25              9  "accroutments"  "tintinnabultion"  "hippocampus"
# 26              9  "accroutments"  "tintinnabultion"  "hippocampus"
# 27              9  "accroutments"  "tintinnabultion"  "hippocampus"
# 28              1  "accroutments"  "tintinnabultion"  "hippocampus"
# 29              9  "accroutments"  "tintinnabultion"  "hippocampus"
# 30              9  "accroutments"  "tintinnabultion"  "hippocampus"
#
#      distractor4   distractor5               prolific_id  story  p_type  \
# 0   "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 1   "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 2   "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 3   "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 4   "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 5   "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 6   "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 7   "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 8   "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 9   "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 10  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 11  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 12  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 13  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 14  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 15  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 16  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 17  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 18  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 19  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 20  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 21  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 22  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 23  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 24  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 25  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 26  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 27  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 28  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 29  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
# 30  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32     12       0
#
#     persp  ...                                           sa_order  \
# 0       2  ...  "For how long has the initiator of the breakup...
# 1       2  ...  "For how long has the initiator of the breakup...
# 2       2  ...  "For how long has the initiator of the breakup...
# 3       2  ...  "For how long has the initiator of the breakup...
# 4       2  ...  "For how long has the initiator of the breakup...
# 5       2  ...  "For how long has the initiator of the breakup...
# 6       2  ...  "For how long has the initiator of the breakup...
# 7       2  ...  "For how long has the initiator of the breakup...
# 8       2  ...  "For how long has the initiator of the breakup...
# 9       2  ...  "For how long has the initiator of the breakup...
# 10      2  ...  "For how long has the initiator of the breakup...
# 11      2  ...  "For how long has the initiator of the breakup...
# 12      2  ...  "For how long has the initiator of the breakup...
# 13      2  ...  "For how long has the initiator of the breakup...
# 14      2  ...  "For how long has the initiator of the breakup...
# 15      2  ...  "For how long has the initiator of the breakup...
# 16      2  ...  "For how long has the initiator of the breakup...
# 17      2  ...  "For how long has the initiator of the breakup...
# 18      2  ...  "For how long has the initiator of the breakup...
# 19      2  ...  "For how long has the initiator of the breakup...
# 20      2  ...  "For how long has the initiator of the breakup...
# 21      2  ...  "For how long has the initiator of the breakup...
# 22      2  ...  "For how long has the initiator of the breakup...
# 23      2  ...  "For how long has the initiator of the breakup...
# 24      2  ...  "For how long has the initiator of the breakup...
# 25      2  ...  "For how long has the initiator of the breakup...
# 26      2  ...  "For how long has the initiator of the breakup...
# 27      2  ...  "For how long has the initiator of the breakup...
# 28      2  ...  "For how long has the initiator of the breakup...
# 29      2  ...  "For how long has the initiator of the breakup...
# 30      2  ...  "For how long has the initiator of the breakup...
#
#                                                recall          A1  \
# 0   arrived at the airport, went through the secur...  " 6 weeks"
# 1   arrived at the airport, went through the secur...  " 6 weeks"
# 2   arrived at the airport, went through the secur...  " 6 weeks"
# 3   arrived at the airport, went through the secur...  " 6 weeks"
# 4   arrived at the airport, went through the secur...  " 6 weeks"
# 5   arrived at the airport, went through the secur...  " 6 weeks"
# 6   arrived at the airport, went through the secur...  " 6 weeks"
# 7   arrived at the airport, went through the secur...  " 6 weeks"
# 8   arrived at the airport, went through the secur...  " 6 weeks"
# 9   arrived at the airport, went through the secur...  " 6 weeks"
# 10  arrived at the airport, went through the secur...  " 6 weeks"
# 11  arrived at the airport, went through the secur...  " 6 weeks"
# 12  arrived at the airport, went through the secur...  " 6 weeks"
# 13  arrived at the airport, went through the secur...  " 6 weeks"
# 14  arrived at the airport, went through the secur...  " 6 weeks"
# 15  arrived at the airport, went through the secur...  " 6 weeks"
# 16  arrived at the airport, went through the secur...  " 6 weeks"
# 17  arrived at the airport, went through the secur...  " 6 weeks"
# 18  arrived at the airport, went through the secur...  " 6 weeks"
# 19  arrived at the airport, went through the secur...  " 6 weeks"
# 20  arrived at the airport, went through the secur...  " 6 weeks"
# 21  arrived at the airport, went through the secur...  " 6 weeks"
# 22  arrived at the airport, went through the secur...  " 6 weeks"
# 23  arrived at the airport, went through the secur...  " 6 weeks"
# 24  arrived at the airport, went through the secur...  " 6 weeks"
# 25  arrived at the airport, went through the secur...  " 6 weeks"
# 26  arrived at the airport, went through the secur...  " 6 weeks"
# 27  arrived at the airport, went through the secur...  " 6 weeks"
# 28  arrived at the airport, went through the secur...  " 6 weeks"
# 29  arrived at the airport, went through the secur...  " 6 weeks"
# 30  arrived at the airport, went through the secur...  " 6 weeks"
#
#                   A2                                    A3        A4  \
# 0   "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 1   "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 2   "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 3   "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 4   "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 5   "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 6   "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 7   "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 8   "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 9   "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 10  "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 11  "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 12  "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 13  "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 14  "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 15  "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 16  "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 17  "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 18  "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 19  "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 20  "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 21  "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 22  "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 23  "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 24  "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 25  "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 26  "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 27  "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 28  "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 29  "not getting on"  "no, didnt think anything was wrong"  "calvin"
# 30  "not getting on"  "no, didnt think anything was wrong"  "calvin"
#
#           A5                   A6   A7         A8
# 0   "1 hour"  "the conveyor belt"  "3"  "economy"
# 1   "1 hour"  "the conveyor belt"  "3"  "economy"
# 2   "1 hour"  "the conveyor belt"  "3"  "economy"
# 3   "1 hour"  "the conveyor belt"  "3"  "economy"
# 4   "1 hour"  "the conveyor belt"  "3"  "economy"
# 5   "1 hour"  "the conveyor belt"  "3"  "economy"
# 6   "1 hour"  "the conveyor belt"  "3"  "economy"
# 7   "1 hour"  "the conveyor belt"  "3"  "economy"
# 8   "1 hour"  "the conveyor belt"  "3"  "economy"
# 9   "1 hour"  "the conveyor belt"  "3"  "economy"
# 10  "1 hour"  "the conveyor belt"  "3"  "economy"
# 11  "1 hour"  "the conveyor belt"  "3"  "economy"
# 12  "1 hour"  "the conveyor belt"  "3"  "economy"
# 13  "1 hour"  "the conveyor belt"  "3"  "economy"
# 14  "1 hour"  "the conveyor belt"  "3"  "economy"
# 15  "1 hour"  "the conveyor belt"  "3"  "economy"
# 16  "1 hour"  "the conveyor belt"  "3"  "economy"
# 17  "1 hour"  "the conveyor belt"  "3"  "economy"
# 18  "1 hour"  "the conveyor belt"  "3"  "economy"
# 19  "1 hour"  "the conveyor belt"  "3"  "economy"
# 20  "1 hour"  "the conveyor belt"  "3"  "economy"
# 21  "1 hour"  "the conveyor belt"  "3"  "economy"
# 22  "1 hour"  "the conveyor belt"  "3"  "economy"
# 23  "1 hour"  "the conveyor belt"  "3"  "economy"
# 24  "1 hour"  "the conveyor belt"  "3"  "economy"
# 25  "1 hour"  "the conveyor belt"  "3"  "economy"
# 26  "1 hour"  "the conveyor belt"  "3"  "economy"
# 27  "1 hour"  "the conveyor belt"  "3"  "economy"
# 28  "1 hour"  "the conveyor belt"  "3"  "economy"
# 29  "1 hour"  "the conveyor belt"  "3"  "economy"
# 30  "1 hour"  "the conveyor belt"  "3"  "economy"
#
# [31 rows x 21 columns]

# %%
data_dict['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h18.58.644']
# Out:
#     story_presses       distractor1         distractor2    distractor3  \
# 0               1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 1               9  "accountrements"  "tinntinnbulation"  "hippocampus"
# 2               9  "accountrements"  "tinntinnbulation"  "hippocampus"
# 3               1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 4               9  "accountrements"  "tinntinnbulation"  "hippocampus"
# 5               9  "accountrements"  "tinntinnbulation"  "hippocampus"
# 6               9  "accountrements"  "tinntinnbulation"  "hippocampus"
# 7               9  "accountrements"  "tinntinnbulation"  "hippocampus"
# 8               1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 9               1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 10              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 11              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 12              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 13              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 14              9  "accountrements"  "tinntinnbulation"  "hippocampus"
# 15              9  "accountrements"  "tinntinnbulation"  "hippocampus"
# 16              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 17              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 18              9  "accountrements"  "tinntinnbulation"  "hippocampus"
# 19              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 20              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 21              9  "accountrements"  "tinntinnbulation"  "hippocampus"
# 22              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 23              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 24              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 25              9  "accountrements"  "tinntinnbulation"  "hippocampus"
# 26              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 27              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 28              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 29              9  "accountrements"  "tinntinnbulation"  "hippocampus"
# 30              9  "accountrements"  "tinntinnbulation"  "hippocampus"
# 31              9  "accountrements"  "tinntinnbulation"  "hippocampus"
#
#      distractor4   distractor5               prolific_id  story  p_type  \
# 0   "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 1   "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 2   "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 3   "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 4   "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 5   "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 6   "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 7   "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 8   "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 9   "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 10  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 11  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 12  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 13  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 14  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 15  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 16  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 17  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 18  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 19  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 20  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 21  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 22  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 23  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 24  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 25  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 26  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 27  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 28  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 29  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 30  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 31  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
#
#     persp  ...                                           sa_order  \
# 0      30  ...  "What is the grocery store like upon entering?\n"
# 1      30  ...  "What is the grocery store like upon entering?\n"
# 2      30  ...  "What is the grocery store like upon entering?\n"
# 3      30  ...  "What is the grocery store like upon entering?\n"
# 4      30  ...  "What is the grocery store like upon entering?\n"
# 5      30  ...  "What is the grocery store like upon entering?\n"
# 6      30  ...  "What is the grocery store like upon entering?\n"
# 7      30  ...  "What is the grocery store like upon entering?\n"
# 8      30  ...  "What is the grocery store like upon entering?\n"
# 9      30  ...  "What is the grocery store like upon entering?\n"
# 10     30  ...  "What is the grocery store like upon entering?\n"
# 11     30  ...  "What is the grocery store like upon entering?\n"
# 12     30  ...  "What is the grocery store like upon entering?\n"
# 13     30  ...  "What is the grocery store like upon entering?\n"
# 14     30  ...  "What is the grocery store like upon entering?\n"
# 15     30  ...  "What is the grocery store like upon entering?\n"
# 16     30  ...  "What is the grocery store like upon entering?\n"
# 17     30  ...  "What is the grocery store like upon entering?\n"
# 18     30  ...  "What is the grocery store like upon entering?\n"
# 19     30  ...  "What is the grocery store like upon entering?\n"
# 20     30  ...  "What is the grocery store like upon entering?\n"
# 21     30  ...  "What is the grocery store like upon entering?\n"
# 22     30  ...  "What is the grocery store like upon entering?\n"
# 23     30  ...  "What is the grocery store like upon entering?\n"
# 24     30  ...  "What is the grocery store like upon entering?\n"
# 25     30  ...  "What is the grocery store like upon entering?\n"
# 26     30  ...  "What is the grocery store like upon entering?\n"
# 27     30  ...  "What is the grocery store like upon entering?\n"
# 28     30  ...  "What is the grocery store like upon entering?\n"
# 29     30  ...  "What is the grocery store like upon entering?\n"
# 30     30  ...  "What is the grocery store like upon entering?\n"
# 31     30  ...  "What is the grocery store like upon entering?\n"
#
#                                                recall       A1        A2   A3  \
# 0   Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 1   Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 2   Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 3   Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 4   Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 5   Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 6   Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 7   Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 8   Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 9   Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 10  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 11  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 12  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 13  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 14  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 15  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 16  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 17  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 18  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 19  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 20  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 21  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 22  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 23  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 24  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 25  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 26  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 27  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 28  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 29  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 30  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 31  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
#
#                       A4                             A5      A6  \
# 0   "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 1   "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 2   "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 3   "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 4   "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 5   "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 6   "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 7   "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 8   "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 9   "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 10  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 11  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 12  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 13  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 14  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 15  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 16  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 17  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 18  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 19  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 20  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 21  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 22  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 23  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 24  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 25  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 26  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 27  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 28  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 29  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 30  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 31  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
#
#                   A7                 A8
# 0   "orange grocers"  "bottle of drink"
# 1   "orange grocers"  "bottle of drink"
# 2   "orange grocers"  "bottle of drink"
# 3   "orange grocers"  "bottle of drink"
# 4   "orange grocers"  "bottle of drink"
# 5   "orange grocers"  "bottle of drink"
# 6   "orange grocers"  "bottle of drink"
# 7   "orange grocers"  "bottle of drink"
# 8   "orange grocers"  "bottle of drink"
# 9   "orange grocers"  "bottle of drink"
# 10  "orange grocers"  "bottle of drink"
# 11  "orange grocers"  "bottle of drink"
# 12  "orange grocers"  "bottle of drink"
# 13  "orange grocers"  "bottle of drink"
# 14  "orange grocers"  "bottle of drink"
# 15  "orange grocers"  "bottle of drink"
# 16  "orange grocers"  "bottle of drink"
# 17  "orange grocers"  "bottle of drink"
# 18  "orange grocers"  "bottle of drink"
# 19  "orange grocers"  "bottle of drink"
# 20  "orange grocers"  "bottle of drink"
# 21  "orange grocers"  "bottle of drink"
# 22  "orange grocers"  "bottle of drink"
# 23  "orange grocers"  "bottle of drink"
# 24  "orange grocers"  "bottle of drink"
# 25  "orange grocers"  "bottle of drink"
# 26  "orange grocers"  "bottle of drink"
# 27  "orange grocers"  "bottle of drink"
# 28  "orange grocers"  "bottle of drink"
# 29  "orange grocers"  "bottle of drink"
# 30  "orange grocers"  "bottle of drink"
# 31  "orange grocers"  "bottle of drink"
#
# [32 rows x 21 columns]

# %%
data_dict['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h18.58.644']
# Out:
#     story_presses       distractor1         distractor2    distractor3  \
# 0               1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 1               9  "accountrements"  "tinntinnbulation"  "hippocampus"
# 2               9  "accountrements"  "tinntinnbulation"  "hippocampus"
# 3               1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 4               9  "accountrements"  "tinntinnbulation"  "hippocampus"
# 5               9  "accountrements"  "tinntinnbulation"  "hippocampus"
# 6               9  "accountrements"  "tinntinnbulation"  "hippocampus"
# 7               9  "accountrements"  "tinntinnbulation"  "hippocampus"
# 8               1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 9               1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 10              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 11              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 12              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 13              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 14              9  "accountrements"  "tinntinnbulation"  "hippocampus"
# 15              9  "accountrements"  "tinntinnbulation"  "hippocampus"
# 16              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 17              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 18              9  "accountrements"  "tinntinnbulation"  "hippocampus"
# 19              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 20              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 21              9  "accountrements"  "tinntinnbulation"  "hippocampus"
# 22              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 23              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 24              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 25              9  "accountrements"  "tinntinnbulation"  "hippocampus"
# 26              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 27              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 28              1  "accountrements"  "tinntinnbulation"  "hippocampus"
# 29              9  "accountrements"  "tinntinnbulation"  "hippocampus"
# 30              9  "accountrements"  "tinntinnbulation"  "hippocampus"
# 31              9  "accountrements"  "tinntinnbulation"  "hippocampus"
#
#      distractor4   distractor5               prolific_id  story  p_type  \
# 0   "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 1   "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 2   "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 3   "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 4   "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 5   "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 6   "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 7   "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 8   "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 9   "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 10  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 11  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 12  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 13  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 14  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 15  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 16  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 17  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 18  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 19  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 20  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 21  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 22  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 23  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 24  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 25  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 26  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 27  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 28  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 29  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 30  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
# 31  "brigadeiro"  "muffuletta"  5bc9e924e642db0001d3a1c5     33       2
#
#     persp  ...                                           sa_order  \
# 0      30  ...  "What is the grocery store like upon entering?\n"
# 1      30  ...  "What is the grocery store like upon entering?\n"
# 2      30  ...  "What is the grocery store like upon entering?\n"
# 3      30  ...  "What is the grocery store like upon entering?\n"
# 4      30  ...  "What is the grocery store like upon entering?\n"
# 5      30  ...  "What is the grocery store like upon entering?\n"
# 6      30  ...  "What is the grocery store like upon entering?\n"
# 7      30  ...  "What is the grocery store like upon entering?\n"
# 8      30  ...  "What is the grocery store like upon entering?\n"
# 9      30  ...  "What is the grocery store like upon entering?\n"
# 10     30  ...  "What is the grocery store like upon entering?\n"
# 11     30  ...  "What is the grocery store like upon entering?\n"
# 12     30  ...  "What is the grocery store like upon entering?\n"
# 13     30  ...  "What is the grocery store like upon entering?\n"
# 14     30  ...  "What is the grocery store like upon entering?\n"
# 15     30  ...  "What is the grocery store like upon entering?\n"
# 16     30  ...  "What is the grocery store like upon entering?\n"
# 17     30  ...  "What is the grocery store like upon entering?\n"
# 18     30  ...  "What is the grocery store like upon entering?\n"
# 19     30  ...  "What is the grocery store like upon entering?\n"
# 20     30  ...  "What is the grocery store like upon entering?\n"
# 21     30  ...  "What is the grocery store like upon entering?\n"
# 22     30  ...  "What is the grocery store like upon entering?\n"
# 23     30  ...  "What is the grocery store like upon entering?\n"
# 24     30  ...  "What is the grocery store like upon entering?\n"
# 25     30  ...  "What is the grocery store like upon entering?\n"
# 26     30  ...  "What is the grocery store like upon entering?\n"
# 27     30  ...  "What is the grocery store like upon entering?\n"
# 28     30  ...  "What is the grocery store like upon entering?\n"
# 29     30  ...  "What is the grocery store like upon entering?\n"
# 30     30  ...  "What is the grocery store like upon entering?\n"
# 31     30  ...  "What is the grocery store like upon entering?\n"
#
#                                                recall       A1        A2   A3  \
# 0   Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 1   Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 2   Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 3   Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 4   Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 5   Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 6   Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 7   Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 8   Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 9   Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 10  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 11  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 12  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 13  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 14  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 15  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 16  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 17  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 18  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 19  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 20  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 21  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 22  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 23  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 24  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 25  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 26  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 27  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 28  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 29  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 30  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
# 31  Miss Bianchi wants to sell cheese from Italy t...  " busy"  "cheese"  "6"
#
#                       A4                             A5      A6  \
# 0   "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 1   "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 2   "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 3   "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 4   "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 5   "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 6   "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 7   "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 8   "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 9   "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 10  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 11  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 12  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 13  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 14  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 15  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 16  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 17  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 18  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 19  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 20  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 21  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 22  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 23  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 24  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 25  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 26  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 27  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 28  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 29  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 30  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
# 31  "23 dollars, cheque"  "miss bianchi, miss morrison"  "1500"
#
#                   A7                 A8
# 0   "orange grocers"  "bottle of drink"
# 1   "orange grocers"  "bottle of drink"
# 2   "orange grocers"  "bottle of drink"
# 3   "orange grocers"  "bottle of drink"
# 4   "orange grocers"  "bottle of drink"
# 5   "orange grocers"  "bottle of drink"
# 6   "orange grocers"  "bottle of drink"
# 7   "orange grocers"  "bottle of drink"
# 8   "orange grocers"  "bottle of drink"
# 9   "orange grocers"  "bottle of drink"
# 10  "orange grocers"  "bottle of drink"
# 11  "orange grocers"  "bottle of drink"
# 12  "orange grocers"  "bottle of drink"
# 13  "orange grocers"  "bottle of drink"
# 14  "orange grocers"  "bottle of drink"
# 15  "orange grocers"  "bottle of drink"
# 16  "orange grocers"  "bottle of drink"
# 17  "orange grocers"  "bottle of drink"
# 18  "orange grocers"  "bottle of drink"
# 19  "orange grocers"  "bottle of drink"
# 20  "orange grocers"  "bottle of drink"
# 21  "orange grocers"  "bottle of drink"
# 22  "orange grocers"  "bottle of drink"
# 23  "orange grocers"  "bottle of drink"
# 24  "orange grocers"  "bottle of drink"
# 25  "orange grocers"  "bottle of drink"
# 26  "orange grocers"  "bottle of drink"
# 27  "orange grocers"  "bottle of drink"
# 28  "orange grocers"  "bottle of drink"
# 29  "orange grocers"  "bottle of drink"
# 30  "orange grocers"  "bottle of drink"
# 31  "orange grocers"  "bottle of drink"
#
# [32 rows x 21 columns]
