# %%
import re
import codecs
import glob
import csv
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import math
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
# %autosave 5
# Out:
# Autosaving every 5 seconds

# %% [markdown]
# # Create a Summary Dashboard of the stories run & combinations of stories and perspectives
#
# #### i. import data_dict

# %%
filename = '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/analysis/parsing_log_file/pickle/data_dict_pilots_b1_b2_b3_b4.p'
data_dict = pickle.load( open( filename, "rb" ) )

# %% [markdown]
# #### ii. exclude participants excluded from short answer analysis

# %%
for key in data_dict:
    if data_dict[key]['prolific_id'].iloc[0] == '5ed1443918f6bd07449d88a5':
        print(key)
    if data_dict[key]['prolific_id'].iloc[0] == '59a817a969b7e70001fe5d38':
        print(key)
# Out:
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/data/finalver_b2/30/199_1_online_exp_2020-06-24_20h41.05.680
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/data/finalver_b3/45/345_1_online_exp_2020-07-16_09h07.09.087

# %%
# Manually exclude these keys
# derived from above
data_dict.pop('/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/data/finalver_b2/30/199_1_online_exp_2020-06-24_20h41.05.680', None)
data_dict.pop('/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/data/finalver_b3/45/345_1_online_exp_2020-07-16_09h07.09.087', None) 
# derived from Excluded participants sheet
data_dict.pop('/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/data/finalver_b1/33/73_1_online_exp_2020-06-10_14h37.05.252', None)
# Out:
#     story_presses    A1 A2 A3 A4 A5 A6   A7   A8 distractor1  ...  \
# 0               9  "  "                 " "  " "        "  "  ...
# 1               9  "  "                 " "  " "        "  "  ...
# 2               1  "  "                 " "  " "        "  "  ...
# 3               9  "  "                 " "  " "        "  "  ...
# 4               9  "  "                 " "  " "        "  "  ...
# 5               9  "  "                 " "  " "        "  "  ...
# 6               9  "  "                 " "  " "        "  "  ...
# 7               1  "  "                 " "  " "        "  "  ...
# 8               9  "  "                 " "  " "        "  "  ...
# 9               9  "  "                 " "  " "        "  "  ...
# 10              9  "  "                 " "  " "        "  "  ...
# 11              9  "  "                 " "  " "        "  "  ...
# 12              9  "  "                 " "  " "        "  "  ...
# 13              9  "  "                 " "  " "        "  "  ...
# 14              9  "  "                 " "  " "        "  "  ...
# 15              9  "  "                 " "  " "        "  "  ...
# 16              1  "  "                 " "  " "        "  "  ...
# 17              9  "  "                 " "  " "        "  "  ...
# 18              9  "  "                 " "  " "        "  "  ...
# 19              9  "  "                 " "  " "        "  "  ...
# 20              9  "  "                 " "  " "        "  "  ...
# 21              9  "  "                 " "  " "        "  "  ...
# 22              9  "  "                 " "  " "        "  "  ...
# 23              9  "  "                 " "  " "        "  "  ...
# 24              9  "  "                 " "  " "        "  "  ...
# 25              9  "  "                 " "  " "        "  "  ...
# 26              9  "  "                 " "  " "        "  "  ...
# 27              9  "  "                 " "  " "        "  "  ...
# 28              9  "  "                 " "  " "        "  "  ...
# 29              9  "  "                 " "  " "        "  "  ...
# 30              9  "  "                 " "  " "        "  "  ...
# 31              9  "  "                 " "  " "        "  "  ...
# 32              1  "  "                 " "  " "        "  "  ...
#
#     distractor3 distractor4  distractor5               prolific_id story  \
# 0           "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 1           "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 2           "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 3           "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 4           "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 5           "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 6           "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 7           "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 8           "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 9           "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 10          "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 11          "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 12          "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 13          "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 14          "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 15          "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 16          "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 17          "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 18          "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 19          "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 20          "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 21          "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 22          "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 23          "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 24          "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 25          "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 26          "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 27          "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 28          "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 29          "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 30          "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 31          "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
# 32          "h"   "bridego"  "muffuleta"  5ed773ad2006c61f224dc9a0    32
#
#     p_type  persp  alt_persp  sa_order  recall
# 0        1      2         30         0     yes
# 1        1      2         30         0     yes
# 2        1      2         30         0     yes
# 3        1      2         30         0     yes
# 4        1      2         30         0     yes
# 5        1      2         30         0     yes
# 6        1      2         30         0     yes
# 7        1      2         30         0     yes
# 8        1      2         30         0     yes
# 9        1      2         30         0     yes
# 10       1      2         30         0     yes
# 11       1      2         30         0     yes
# 12       1      2         30         0     yes
# 13       1      2         30         0     yes
# 14       1      2         30         0     yes
# 15       1      2         30         0     yes
# 16       1      2         30         0     yes
# 17       1      2         30         0     yes
# 18       1      2         30         0     yes
# 19       1      2         30         0     yes
# 20       1      2         30         0     yes
# 21       1      2         30         0     yes
# 22       1      2         30         0     yes
# 23       1      2         30         0     yes
# 24       1      2         30         0     yes
# 25       1      2         30         0     yes
# 26       1      2         30         0     yes
# 27       1      2         30         0     yes
# 28       1      2         30         0     yes
# 29       1      2         30         0     yes
# 30       1      2         30         0     yes
# 31       1      2         30         0     yes
# 32       1      2         30         0     yes
#
# [33 rows x 21 columns]

# %% [markdown]
# #### iii. exclude participants excluded from segmentation analysis

# %%
del data_dict['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/data/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_12h52.50.131']
del data_dict['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/data/finalver_b1/33/145_1_online_exp_2020-06-10_15h14.14.911']
del data_dict['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/data/finalver_b1/33/171_1_online_exp_2020-06-10_21h32.27.534']
del data_dict['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/data/finalver_b3/45/418_1_online_exp_2020-07-16_09h12.22.806']

# %% [markdown]
# ## I. Distribution of Stories
#
# ### A. List the stories

# %%
stories = []

for key in data_dict:
    stories.append(data_dict[key]['story'].iloc[0])

# %% [markdown]
# ### B. Count the stories

# %%
all_stories = [11, 12, 13, 14, 21, 22, 23, 24, 31, 32, 33, 34, 41, 42, 43, 44]
story_count = []

for i in all_stories:
    story_count.append(stories.count(i))

# %% [markdown]
# ### C. Plot the distribution

# %%
plt.figure(figsize=(20,10))
yint = range(0, math.ceil(max(story_count))+1)
x = np.arange(16)
plt.bar(x, story_count)
plt.yticks(yint)
_ = plt.xticks(x, all_stories)

# %% [markdown]
# ## II. Distribution of the Combinations of Stories and Perspectives
#
# ### A. Finding the distribution of combinations

# %%
comb_distr = np.zeros((3, 16))

for key in data_dict:
    this_story = data_dict[key]['story'].iloc[0]
    this_type = data_dict[key]['p_type'].iloc[0]
    if this_story == 11:
        if this_type == 0:
            comb_distr[0,0] += 1
        if this_type == 1:
            comb_distr[1,0] += 1
        if this_type == 2:
            comb_distr[2,0] += 1
    if this_story == 12:
        if this_type == 0:
            comb_distr[0,1] += 1
        if this_type == 1:
            comb_distr[1,1] += 1
        if this_type == 2:
            comb_distr[2,1] += 1
    if this_story == 13:
        if this_type == 0:
            comb_distr[0,2] += 1
        if this_type == 1:
            comb_distr[1,2] += 1
        if this_type == 2:
            comb_distr[2,2] += 1
    if this_story == 14:
        if this_type == 0:
            comb_distr[0,3] += 1
        if this_type == 1:
            comb_distr[1,3] += 1
        if this_type == 2:
            comb_distr[2,3] += 1
    if this_story == 21:
        if this_type == 0:
            comb_distr[0,4] += 1
        if this_type == 1:
            comb_distr[1,4] += 1
        if this_type == 2:
            comb_distr[2,4] += 1
    if this_story == 22:
        if this_type == 0:
            comb_distr[0,5] += 1
        if this_type == 1:
            comb_distr[1,5] += 1
        if this_type == 2:
            comb_distr[2,5] += 1
    if this_story == 23:
        if this_type == 0:
            comb_distr[0,6] += 1
        if this_type == 1:
            comb_distr[1,6] += 1
        if this_type == 2:
            comb_distr[2,6] += 1
    if this_story == 24:
        if this_type == 0:
            comb_distr[0,7] += 1
        if this_type == 1:
            comb_distr[1,7] += 1
        if this_type == 2:
            comb_distr[2,7] += 1
    if this_story == 31:
        if this_type == 0:
            comb_distr[0,8] += 1
        if this_type == 1:
            comb_distr[1,8] += 1
        if this_type == 2:
            comb_distr[2,8] += 1
    if this_story == 32:
        if this_type == 0:
            comb_distr[0,9] += 1
        if this_type == 1:
            comb_distr[1,9] += 1
        if this_type == 2:
            comb_distr[2,9] += 1
    if this_story == 33:
        if this_type == 0:
            comb_distr[0,10] += 1
        if this_type == 1:
            comb_distr[1,10] += 1
        if this_type == 2:
            comb_distr[2,10] += 1
    if this_story == 34:
        if this_type == 0:
            comb_distr[0,11] += 1
        if this_type == 1:
            comb_distr[1,11] += 1
        if this_type == 2:
            comb_distr[2,11] += 1
    if this_story == 41:
        if this_type == 0:
            comb_distr[0,12] += 1
        if this_type == 1:
            comb_distr[1,12] += 1
        if this_type == 2:
            comb_distr[2,12] += 1
    if this_story == 42:
        if this_type == 0:
            comb_distr[0,13] += 1
        if this_type == 1:
            comb_distr[1,13] += 1
        if this_type == 2:
            comb_distr[2,13] += 1
    if this_story == 43:
        if this_type == 0:
            comb_distr[0,14] += 1
        if this_type == 1:
            comb_distr[1,14] += 1
        if this_type == 2:
            comb_distr[2,14] += 1
    if this_story == 44:
        if this_type == 0:
            comb_distr[0,15] += 1
        if this_type == 1:
            comb_distr[1,15] += 1
        if this_type == 2:
            comb_distr[2,15] += 1

# %% [markdown]
# ### B. Plotting the Distribution of Combinations: heatmap

# %%
fig, ax = plt.subplots(figsize=(20, 10))
im = ax.imshow(comb_distr)


# We want to show all ticks...
ax.set_xticks(np.arange(len(all_stories)))
ax.set_yticks(np.arange(3))
# ... and label them with the respective list entries
_ = ax.set_xticklabels(all_stories)
_ = ax.set_yticklabels(['no prime', 'location prime', 'social prime'])

# Loop over data dimensions and create text annotations.
for i in range(3):
    for j in range(len(all_stories)):
        text = ax.text(j, i, comb_distr[i, j],
                       ha="center", va="center", color="w")

ax.set_title("Distribution of Combinations of Stories and Primes")
fig.tight_layout()
fig.savefig('distr.png')

# %% [markdown]
# ## C. Preparing vector for online experiment
# ### 1. Create a vector with the number of remaining subjects for each condition for Online Exp
# ### - organized as [11-np, 11-l, 11-s, 12-np, 12-l, 12-s...]

# %%
# Flatten the comb_distr array in column-major order
fl_comb_distr = comb_distr.flatten("F")

# For each element, find out how much smaller the number is than 6
remaining = np.zeros((fl_comb_distr.shape[0]))
for i in range(0, fl_comb_distr.shape[0]):
    if fl_comb_distr[i] < 6:
        remaining[i] = 6 - fl_comb_distr[i]

# For each element, find out how much smaller the number is than 5, indicating how many participants we 
# actually need
remaining_5 = np.zeros((fl_comb_distr.shape[0]))
for i in range(0, fl_comb_distr.shape[0]):
    if fl_comb_distr[i] < 5:
        remaining_5[i] = 5 - fl_comb_distr[i]
        
# Find the total number of remaining subjects
print(np.sum(fl_comb_distr), " participants collected")
print(np.sum(remaining_5), " participants needed")
print(np.sum(remaining), " participants 'needed' for the experiment")
# Out:
# 166.0  participants collected
# 82.0  participants needed
# 124.0  participants 'needed' for the experiment

# %% [markdown]
# ### 2. Find the cumsum of participants

# %%
cs = np.cumsum(remaining)

# %%
cs
# Out:
# array([  0.,   2.,   6.,   8.,  12.,  14.,  16.,  21.,  26.,  27.,  30.,
#         33.,  38.,  39.,  42.,  42.,  45.,  46.,  48.,  48.,  50.,  52.,
#         55.,  57.,  60.,  63.,  65.,  67.,  70.,  74.,  74.,  75.,  78.,
#         83.,  83.,  87.,  91.,  95., 100., 104., 104., 109., 111., 113.,
#        116., 118., 121., 124.])
