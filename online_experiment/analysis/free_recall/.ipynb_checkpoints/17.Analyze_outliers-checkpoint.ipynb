# %% [markdown]
# # Make Story Vectors
# ## 12/3/20
# ## Make a dict, where for each story there is another dict with keys: 0, 1, 2, containing wvs for each participant
# ## 1/21/21 - adding more information about each recall

# %%
import pandas as pd
import numpy as np
import plotly.graph_objs as go
import plotly.plotly as py
import plotly
import os
import glob
import math
import statistics
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import copy
from random import randrange
from sklearn.metrics import jaccard_score
import random

from sklearn.decomposition import PCA #for cluster analysis
from gensim.models import KeyedVectors #for word embeddings
import matplotlib.pyplot as plt #for plotting
import os #for importing
import pickle #for loading transcripts
from scipy.stats import pearsonr 

# from _DRAFT_20200604_functions import * #includes constants and score function
from tqdm import tqdm_notebook #for progress bar

# %autosave 5
# Out:
# Autosaving every 5 seconds

# %% [markdown]
# # I. Imports
# ## A. Participant Data and Summary of Data

# %%
filename = '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/analysis/segment/usable_data'
filename_sums = '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/analysis/segment/sums_usable_data'
data_dict = pickle.load( open( filename, "rb" ) )
sums = pickle.load( open( filename_sums, "rb" ) )
len(data_dict)
# Out:
# 316

# %% [markdown]
# ## B. Importing wiki vectors

# %%
wikipath = 'rolando/wiki-news-300d-1M.vec'
wv_model = KeyedVectors.load_word2vec_format(wikipath)

# %% [markdown]
# # II. Functions

# %%
wv_dim = 300

# FastText preprocessing, based on bittlingmayer/ft_wiki_preproc.py
# Remove special characters, put spaces between all tokens
SUB = ["s/’/'/g", "s/′/'/g", "s/''/ /g", "s/'/ ' /g", 's/“/"/g', 's/”/"/g', 's/"/ /g', "s/\\./ \\. /g", "s/<br \\/>/ /g", "s/, / , /g", "s/(/ ( /g", "s/)/ ) /g", "s/\\!/ \\! /g", "s/\\?/ \\? /g", "s/\\;/ /g", "s/\\:/ /g", "s/-/ - /g", "s/=/ /g", "s/=/ /g", "s/*/ /g", "s/|/ /g", "s/«/ /g", 
       "s/…/ /g", "s/‘/ /g", "s/í/ /g", "s/ñ/ /g", "s/\x84/ /g", "s/î/ /g", "s/ó/ /g", "s/\x83/ /g", "s/ï/ /g", "s/õ/ /g",
       "s/ò/ /g", "s/,/ /g", "s/ô/ /g", "s/\x92/ /g", "s/é/ /g", "s/\x8e/ /g", "s/â\x80¦/ /g", "s/\x91/ /g", "s/\x93/ /g",
       "s/\x94/ /g", "s/ã®/ /g", "s/ã¨/ /g", "s/ã©/ /g",
       "s/\â\x80\x99/ /g", "s/â\x80\x9c/ /g", "s/â\x80\x9d/ /g", "s/â\x80\x99/ /g", "s/â\x80\x9c/ /g", "s/â\x80\x98/ /g",
       "s/â/ /g"]

def __normalize_text(s):
    for sg in SUB:
        rep = sg.replace('\\','').split('/')
        s = s.replace(rep[1], rep[2])
    s = s.replace('/',' ')
    return s

def __spaces(s):
    return ' '.join(s.split())

def __digits(s):
    return ''.join(filter(lambda c: not c.isdigit(), s))

# def preproc(s):
#     return __punctuation(__spaces(__digits(__normalize_text(s.lower()))))

def preproc(s):
    return (__spaces(__digits(__normalize_text(s.lower()))))

def __punctuation(s):
    return s.translate(str.maketrans('', '', string.punctuation))

def word2vecSent(sentence, model = 'fasttext'):
    wv_dim = 300 #for glove and fasttext
    
    if model == 'glove':
        wvmodel = glove_model
    elif model == 'fasttext':
        wvmodel = wv_model
        
    words = preproc(sentence).split(' ')
    wv = np.zeros((len(words), wv_dim))
    for i in range(len(words)):
        if words[i] in wvmodel.vocab:
            wv[i,:] = wvmodel.word_vec(words[i])
    
    return wv

# %% [markdown]
# ## III. Making the story vectors
# ### A. Organize free recalls in dict
# #### dict[story]{0: [np recalls]; 1: [l recalls]; 2: [s recalls]}

# %%
recalls = {}

#get the key and prolific id 

for key in data_dict:
    # Making a column with prolific id in first row and recall in second
    this_partc = np.zeros((1,3), dtype=object)
    this_partc[0] = data_dict[key]['recall'][0]
    this_partc[0,1] = key
    this_partc[0,2] = data_dict[key]['prolific_id'][0]
    # Naming this story
    this_story = data_dict[key]['story'][0]
    # Naming this perspective
    this_persp = data_dict[key]['p_type'][0]
    if isinstance(this_partc[0][0], float):
        print(key, '\nthis story:', this_story, "this_persp: ", this_persp)
        pass
    else:
        if this_story in recalls:
            if this_persp in recalls[this_story]:
                recalls[this_story][this_persp] = np.vstack((recalls[this_story][this_persp],this_partc))
            else:
                recalls[this_story][this_persp] = this_partc
        else:
            recalls[this_story] = {this_persp: this_partc}
# Out:
# (1, 3)
# (1, 3)
# (1, 3)
# (1, 3)
# (1, 3)
# (1, 3)
# (2, 3)
# (2, 3)
# (1, 3)
# (2, 3)
# (3, 3)
# (2, 3)
# (1, 3)
# (1, 3)
# (1, 3)
# (1, 3)
# (1, 3)
# (1, 3)
# (4, 3)
# (2, 3)
# (1, 3)
# (2, 3)
# (2, 3)
# (2, 3)
# (2, 3)
# (2, 3)
# (2, 3)
# (2, 3)
# (1, 3)
# (3, 3)
# (2, 3)
# (2, 3)
# (3, 3)
# (2, 3)
# (2, 3)
# (5, 3)
# (3, 3)
# (3, 3)
# (3, 3)
# (3, 3)
# (2, 3)
# (2, 3)
# (3, 3)
# (2, 3)
# (2, 3)
# (4, 3)
# (1, 3)
# (2, 3)
# (2, 3)
# (2, 3)
# (2, 3)
# (4, 3)
# (2, 3)
# (2, 3)
# (3, 3)
# (4, 3)
# (3, 3)
# (2, 3)
# (2, 3)
# (3, 3)
# (4, 3)
# (3, 3)
# (3, 3)
# (5, 3)
# (2, 3)
# (2, 3)
# (3, 3)
# (3, 3)
# (5, 3)
# (2, 3)
# (4, 3)
# (4, 3)
# (2, 3)
# (4, 3)
# (2, 3)
# (4, 3)
# (2, 3)
# (3, 3)
# (3, 3)
# (2, 3)
# (3, 3)
# (5, 3)
# (5, 3)
# (3, 3)
# (4, 3)
# (2, 3)
# (6, 3)
# (3, 3)
# (3, 3)
# (2, 3)
# (3, 3)
# (4, 3)
# (3, 3)
# (2, 3)
# (6, 3)
# (6, 3)
# (4, 3)
# (3, 3)
# (6, 3)
# (4, 3)
# (5, 3)
# (5, 3)
# (3, 3)
# (3, 3)
# (3, 3)
# (5, 3)
# (6, 3)
# (3, 3)
# (4, 3)
# (3, 3)
# (4, 3)
# (2, 3)
# (3, 3)
# (2, 3)
# (2, 3)
# (4, 3)
# (3, 3)
# (4, 3)
# (7, 3)
# (5, 3)
# (4, 3)
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/data/finalver_b5/78/131_1_online_exp_2020-09-29_01h42.48.208
# this story: 11 this_persp:  2
# (2, 3)
# (3, 3)
# (4, 3)
# (3, 3)
# (4, 3)
# (4, 3)
# (5, 3)
# (3, 3)
# (6, 3)
# (2, 3)
# (3, 3)
# (8, 3)
# (5, 3)
# (6, 3)
# (5, 3)
# (5, 3)
# (3, 3)
# (5, 3)
# (5, 3)
# (6, 3)
# (5, 3)
# (6, 3)
# (7, 3)
# (6, 3)
# (5, 3)
# (6, 3)
# (4, 3)
# (4, 3)
# (5, 3)
# (4, 3)
# (5, 3)
# (6, 3)
# (3, 3)
# (4, 3)
# (4, 3)
# (4, 3)
# (5, 3)
# (3, 3)
# (4, 3)
# (7, 3)
# (6, 3)
# (7, 3)
# (8, 3)
# (4, 3)
# (7, 3)
# (8, 3)
# (3, 3)
# (4, 3)
# (3, 3)
# (4, 3)
# (4, 3)
# (7, 3)
# (5, 3)
# (5, 3)
# (5, 3)
# (6, 3)
# (5, 3)
# (6, 3)
# (7, 3)
# (3, 3)
# (4, 3)
# (7, 3)
# (2, 3)
# (3, 3)
# (6, 3)
# (6, 3)
# (7, 3)
# (9, 3)
# (7, 3)
# (4, 3)
# (5, 3)
# (5, 3)
# (6, 3)
# (4, 3)
# (5, 3)
# (7, 3)
# (8, 3)
# (9, 3)
# (4, 3)
# (5, 3)
# (6, 3)
# (8, 3)
# (6, 3)
# (8, 3)
# (7, 3)
# (7, 3)
# (8, 3)
# (6, 3)
# (7, 3)
# (9, 3)
# (10, 3)
# (8, 3)
# (4, 3)
# (5, 3)
# (6, 3)
# (6, 3)
# (6, 3)
# (7, 3)
# (6, 3)
# (9, 3)
# (6, 3)
# (7, 3)
# (8, 3)
# (5, 3)
# (8, 3)
# (5, 3)
# (6, 3)
# (4, 3)
# (8, 3)
# (6, 3)
# (7, 3)
# (3, 3)
# (4, 3)
# (2, 3)
# (5, 3)
# (2, 3)
# (4, 3)
# (6, 3)
# (5, 3)
# (4, 3)
# (2, 3)
# (2, 3)
# (5, 3)
# (3, 3)
# (5, 3)
# (6, 3)
# (3, 3)
# (4, 3)
# (4, 3)
# (4, 3)
# (5, 3)
# (3, 3)
# (4, 3)
# (5, 3)
# (5, 3)
# (5, 3)
# (5, 3)
# (5, 3)
# (6, 3)
# (5, 3)
# (6, 3)
# (5, 3)
# (6, 3)
# (5, 3)
# (6, 3)
# (3, 3)
# (7, 3)
# (6, 3)
# (7, 3)
# (3, 3)
# (4, 3)
# (4, 3)
# (6, 3)
# (5, 3)
# (4, 3)
# (5, 3)
# (6, 3)
# (5, 3)
# (5, 3)
# (7, 3)
# (6, 3)
# (6, 3)

# %%
n = 0
for key in recalls:
    for i in range(0,3):
        n += recalls[11][1].shape[0]
        
print(n)
# Out:
# 384

# %% [markdown]
# ### B. Remove excluded participant from sums

# %%
sums[11][3] = 6
sums[11][0] = 23

# %% [markdown]
# ### B. Getting Word Vectors for each free recall
# #### Output: dict w same structure as recalls

# %%
len(recalls[key][i])
# Out:
# 5

# %%
keys = [11, 12, 13, 14, 21, 22, 23, 24, 31, 32, 33, 34, 41, 42, 43, 44]

wv_matrices = {}
keys_ids = np.zeros((0,2))

# Iterating through each key
for key in keys:
    print(key)
    # Iterating through each priming type
    for i in range(0,3):
        # Get the number of participants in that priming group for that story
        partic_n = len(recalls[key][i])
        # Make the matrix containing the word vectors for each participants' recall
        wv_matrix = np.zeros((partic_n, wv_dim))
        for j in range(0, partic_n):
            # Get the recall for that participant
            this_recall = recalls[key][i][j][0]
            # Get the key
            this_key = recalls[key][i][j][1]
            # Get the prolific id
            this_id = recalls[key][i][j][2]
            # Get the wv for that recall
            this_vector = np.mean(word2vecSent(this_recall), axis = 0)
            # Add wv to matrix
            wv_matrix[j, :] = this_vector
            # Create matrix with this_key and this_id
            this_matrix = np.array([this_key, this_id])
            # Add key and prolific id to keys_ids matrix
            keys_ids = np.vstack((keys_ids, this_matrix))
        if key in wv_matrices:
            wv_matrices[key][i] = wv_matrix
        else:
            wv_matrices[key] = {i: wv_matrix}
# Out:
# 11
# 12
# 13
# 14
# 21
# 22
# 23
# 24
# 31
# 32
# 33
# 34
# 41
# 42
# 43
# 44

# %%
s = 0

for key in sums:
    s += sums[key][0]
    
print(s)
# Out:
# 315

# %%
m = 0

for key in wv_matrices:
    for i in range(0,3):
        m += wv_matrices[key][i].shape[0]
        
print(m)
# Out:
# 315

# %%
keys_ids.shape
# Out:
# (315, 2)

# %% [markdown]
# ### C. Export Word Vector Matrices and sums

# %%
pickle.dump( wv_matrices, open( 'story_vectors', "wb" ) )
pickle.dump( sums, open( 'new_sums', "wb" ) )
pickle.dump( keys_ids, open( 'ids_recall', "wb" ) )

# %%
data_dict['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/data/finalver_b8/10/1_1_online_exp_2020-11-20_12h31.55.742']
# Out:
#     story_presses          A1           A2                  A3     A4      A5  \
# 0               1  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 1               1  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 2               9  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 3               1  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 4               1  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 5               1  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 6               1  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 7               9  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 8               1  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 9               1  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 10              9  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 11              1  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 12              9  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 13              1  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 14              1  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 15              9  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 16              1  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 17              1  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 18              9  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 19              1  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 20              1  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 21              1  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 22              1  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 23              1  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 24              1  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 25              1  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 26              1  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 27              9  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 28              1  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 29              1  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
# 30              1  "8 months"  "compromis"  "yes, frustration"  "cat"  "busy"
#
#                A6         A7          A8      distractor1  ...    distractor3  \
# 0   "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 1   "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 2   "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 3   "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 4   "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 5   "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 6   "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 7   "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 8   "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 9   "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 10  "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 11  "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 12  "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 13  "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 14  "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 15  "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 16  "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 17  "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 18  "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 19  "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 20  "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 21  "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 22  "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 23  "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 24  "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 25  "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 26  "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 27  "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 28  "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 29  "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
# 30  "pasta sauce"  "3 empty"  "not sure"  "accoutrements"  ...  "hippocampus"
#
#      distractor4   distractor5               prolific_id story  p_type  persp  \
# 0   "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 1   "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 2   "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 3   "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 4   "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 5   "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 6   "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 7   "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 8   "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 9   "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 10  "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 11  "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 12  "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 13  "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 14  "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 15  "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 16  "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 17  "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 18  "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 19  "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 20  "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 21  "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 22  "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 23  "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 24  "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 25  "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 26  "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 27  "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 28  "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 29  "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
# 30  "brigadeiro"  "muffuletta"  5faa598de2b35a341189d27c    13       2     10
#
#     alt_persp  sa_order                                             recall
# 0           3         0  A couple enters a grocery store. They are prep...
# 1           3         0  A couple enters a grocery store. They are prep...
# 2           3         0  A couple enters a grocery store. They are prep...
# 3           3         0  A couple enters a grocery store. They are prep...
# 4           3         0  A couple enters a grocery store. They are prep...
# 5           3         0  A couple enters a grocery store. They are prep...
# 6           3         0  A couple enters a grocery store. They are prep...
# 7           3         0  A couple enters a grocery store. They are prep...
# 8           3         0  A couple enters a grocery store. They are prep...
# 9           3         0  A couple enters a grocery store. They are prep...
# 10          3         0  A couple enters a grocery store. They are prep...
# 11          3         0  A couple enters a grocery store. They are prep...
# 12          3         0  A couple enters a grocery store. They are prep...
# 13          3         0  A couple enters a grocery store. They are prep...
# 14          3         0  A couple enters a grocery store. They are prep...
# 15          3         0  A couple enters a grocery store. They are prep...
# 16          3         0  A couple enters a grocery store. They are prep...
# 17          3         0  A couple enters a grocery store. They are prep...
# 18          3         0  A couple enters a grocery store. They are prep...
# 19          3         0  A couple enters a grocery store. They are prep...
# 20          3         0  A couple enters a grocery store. They are prep...
# 21          3         0  A couple enters a grocery store. They are prep...
# 22          3         0  A couple enters a grocery store. They are prep...
# 23          3         0  A couple enters a grocery store. They are prep...
# 24          3         0  A couple enters a grocery store. They are prep...
# 25          3         0  A couple enters a grocery store. They are prep...
# 26          3         0  A couple enters a grocery store. They are prep...
# 27          3         0  A couple enters a grocery store. They are prep...
# 28          3         0  A couple enters a grocery store. They are prep...
# 29          3         0  A couple enters a grocery store. They are prep...
# 30          3         0  A couple enters a grocery store. They are prep...
#
# [31 rows x 21 columns]

# %%
recalls[11][0][0]
# Out:
# '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/data/pilot1/7/PARTICIPANT_1_online_exp_2020-05-06_20h00.18.643'
