# %% [markdown]
# # Analysis of Short Answer Scores #3
# ## SA_pilots_b1 minus the person in story 12, Alex, Tara, Ally, Tony, Elen
# ## SA_b2_b3 Alex, Ally, Tony, Elen
# ## SA_b4-b8 Alex, Ally, Tony, Elen
# ## Jan 8, 2020
# ### All scored short answers

# %%
import pandas as pd
import numpy as np
import plotly.graph_objs as go
import plotly.plotly as py
import plotly
import os
import glob
import math
import statistics
import matplotlib.pyplot as plt
import seaborn as sns
import copy
import matplotlib.patches as mpatches
import random
# %autosave 5
# Out:
# Autosaving every 5 seconds

# %% [markdown]
# # I. Importing scored sheets from different scorers

# %%
#getting filenames

# ROUND 1
# alex
directory_ar_1 = '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/analysis/short_answers/scored/pilots_b1/alex'
filenames_ar_1 = glob.glob(directory_ar_1+ '/*.xlsx')

# tara
directory_tk = '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/analysis/short_answers/scored/pilots_b1/tara'
filenames_tk = glob.glob(directory_tk+ '/*.xlsx')

# ally
directory_al_1 = '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/analysis/short_answers/scored/pilots_b1/ally'
filenames_al_1 = glob.glob(directory_al_1 + '/*.xlsx')

# tony
directory_t_1 = '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/analysis/short_answers/scored/pilots_b1/tony'
filenames_t_1 = glob.glob(directory_t_1 + '/*.xlsx')

# elen
directory_t_1 = '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/analysis/short_answers/scored/pilots_b1/elen'
filenames_e_1 = glob.glob(directory_t_1 + '/*.xlsx')

# ROUND 2
# alex
directory_ar_2 = '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/analysis/short_answers/scored/b2_b3/alex'
filenames_ar_2 = glob.glob(directory_ar_2+ '/*.xlsx')

# ally
directory_al_2 = '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/analysis/short_answers/scored/b2_b3/ally'
filenames_al_2 = glob.glob(directory_al_2+ '/*.xlsx')

# tony
directory_t_2 = '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/analysis/short_answers/scored/b2_b3/tony'
filenames_t_2 = glob.glob(directory_t_2+ '/*.xlsx')

# elen
directory_e_2 = '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/analysis/short_answers/scored/b2_b3/elen'
filenames_e_2 = glob.glob(directory_e_2+ '/*.xlsx')

# ROUND 3
# alex
directory_ar_3 = '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/analysis/short_answers/scored/b4_b8/alex'
filenames_ar_3 = glob.glob(directory_ar_3+ '/*.xlsx')

# ally
directory_al_3 = '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/analysis/short_answers/scored/b4_b8/ally'
filenames_al_3 = glob.glob(directory_al_3+ '/*.xlsx')

# tony
directory_t_3 = '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/analysis/short_answers/scored/b4_b8/tony'
filenames_t_3 = glob.glob(directory_t_3+ '/*.xlsx')

# elen
directory_e_3 = '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/analysis/short_answers/scored/b4_b8/elen'
filenames_e_3 = glob.glob(directory_e_3+ '/*.xlsx')

# Importings files

# ROUND 1
#alex
rs_dfs_ar_1 = []

for filename in filenames_ar_1:
    rs_dfs_ar_1.append(pd.read_excel(filename))

#tara
rs_dfs_tk = []

for filename in filenames_tk:
    rs_dfs_tk.append(pd.read_excel(filename))
    
#ally
rs_dfs_al_1 = []

for filename in filenames_al_1:
    rs_dfs_al_1.append(pd.read_excel(filename))
    
# tony
rs_dfs_t_1 = []

for filename in filenames_t_1:
    rs_dfs_t_1.append(pd.read_excel(filename))

# elen
rs_dfs_e_1 = []

for filename in filenames_e_1:
    rs_dfs_e_1.append(pd.read_excel(filename))
    
# ROUND 2
#alex
rs_dfs_ar_2 = []

for filename in filenames_ar_2:
    rs_dfs_ar_2.append(pd.read_excel(filename))
    
#ally
rs_dfs_al_2 = []

for filename in filenames_al_2:
    rs_dfs_al_2.append(pd.read_excel(filename))
    
# tony
rs_dfs_t_2 = []

for filename in filenames_t_2:
    rs_dfs_t_2.append(pd.read_excel(filename))

# elen
rs_dfs_e_2 = []

for filename in filenames_e_2:
    rs_dfs_e_2.append(pd.read_excel(filename))
    
# ROUND 3
#alex
rs_dfs_ar_3 = []

for filename in filenames_ar_3:
    rs_dfs_ar_3.append(pd.read_excel(filename))
    
#ally
rs_dfs_al_3 = []

for filename in filenames_al_3:
    rs_dfs_al_3.append(pd.read_excel(filename))
    
# tony
rs_dfs_t_3 = []

for filename in filenames_t_3:
    rs_dfs_t_3.append(pd.read_excel(filename))

# elen
rs_dfs_e_3 = []

for filename in filenames_e_3:
    rs_dfs_e_3.append(pd.read_excel(filename))
    
    
    
print('done!')
# Out:
# done!

# %%
rs_dfs_t_2
# Out:
# [         date               prolific_id  story  persp  p_type  \
#  0  2020-07-30  5d6a24c4f186b3001ae5dfeb     11      1       0
#  1  2020-07-30  5e3adfc595ff562fbdd130fa     11      1       1
#  2  2020-07-30  5e93138a7d69590115fa1e21     11      1       1
#  3  2020-07-30  5d026ba86c626e0019202f6a     11      1       0
#  4  2020-07-30  5e9fec0f0450b519deaa43a5     11     10       2
#  5  2020-07-30  5ead3fe551c1bb0009b78154     11      1       0
#  6  2020-07-30  5d88b1c27250e90001c40cfc     11      1       1
#
#                                                     1  q1  \
#  0                  "black and white chequered floor"   1
#  1  " Like a diner with checkerboard tiles and a l...   2
#  2                                     " muted decor"   0
#  3                                " It was 80s diner"   1
#  4                              "Like a 1970s diner."   1
#  5                                   "well decorated"   0
#  6  " 70s style diner, with red and black chairs a...   2
#
#                                         2  q2  \
#  0                           "extensive "   0
#  1  "They have silly names for the food."   2
#  2           "laminated with silly names"   3
#  3      "single sheet that are laminated"   2
#  4                            "laminated"   2
#  5                            "ice cream"   0
#  6                                    NaN   0
#
#                                                     3  ...  \
#  0                "a burger no tomatoes and a reuben"  ...
#  1  "Thomas ordered a burger with no tomatoes and ...  ...
#  2                              "burger and ?ruffin?"  ...
#  3  "familiar orders I only remeber the Reuben Sad...  ...
#  4      "A burger and something I did not recognise."  ...
#  5                                   "different food"  ...
#  6                     "burger, not tomato and ruben"  ...
#
#                                                     4 q4  \
#  0                     "he thought it tasted of fish"  1
#  1                                                NaN  0
#  2       "burger tasted bitter. Tom did not like it."  1
#  3                     "Thomas did not like the food"  1
#  4  "She did not eat, and he did not like the burg...  1
#  5  "thomas did not like the food because of the s...  1
#  6                         "Foul tasting so not well"  0
#
#                                                     5 q5  \
#  0                                          " a week"  0
#  1                                         "2 months"  3
#  2                                  "for some months"  1
#  3  "Past couple of months since thinking of job c...  1
#  4                                " For a while now."  0
#  5                                     " 1 to 2years"  0
#  6                                       "two months"  3
#
#                                                     6 q6  \
#  0            "he wanted to focus on his career more"  2
#  1               "He is considering changing careers"  2
#  2              "he wanted to review his career path"  2
#  3  "He is going for a job change and doesnt think...  1
#  4  "Wants to focus on developing career on his own."  3
#  5  "thomas want to break up so that he can concen...  2
#  6              "to focus on figuring out his career"  2
#
#                                                     7 q7  \
#  0                 "no she thought it was going well"  2
#  1  "Sadie wants to stay together and suggests tha...  3
#  2  "no she thought everything was going fine. She...  3
#  3  "No she thinks they can just change how much t...  3
#  4  "No, she did not, and she was prepared to work...  2
#  5                                               "no"  2
#  6  "no and they can work on how much time they sp...  3
#
#                                                     8 q8
#  0  "sadie a beatles poster and something else i f...  2
#  1  "Sadie wants her polaroid camera and beatles p...  3
#  2  "Sadie wants her Polaroid and Beatles poster b...  3
#  3  "Sadie wants her polaroid camera and Beatles p...  3
#  4              "Beatles poster and polaroid camera."  2
#  5                                            "sadie"  1
#  6          "sadie wants a poster and something else"  2
#
#  [7 rows x 21 columns],
#           date               prolific_id  story  persp  p_type              1  \
#  0  2020-07-30  5da250b1106ffc00109177c8     12     10       2   "45 minutes"
#  1  2020-07-30  5d7fd2a5987f70001602d95b     12      2       1  " 20 minutes"
#  2  2020-07-30  5e53036cd91a8232a99e60fb     12     10       2         "2hrs"
#  3  2020-07-30  5ce5b9844cd8130019acba32     12      2       0       "1 hour"
#
#     q1                               2  q2              3  ...  \
#  0   3  "there is a guard change over"   2  "Terminal 3A"  ...
#  1   0             "the conveyer belt"   0           "43"  ...
#  2   0   "security guard shift change"   3          "a82"  ...
#  3   1             "the conveyor belt"   0            "3"  ...
#
#                       4 q4                                           5 q5  \
#  0            "33A 36F"  2                             " a few months"  0
#  1  "separate sections"  0                               "for a while"  0
#  2        "33a and 36f"  2  " 6 weeks before the vacation was planned"  3
#  3            "economy"  1                                  " 6 weeks"  3
#
#                                                  6 q6  \
#  0         "their personalities are incompatible."  3
#  1  "she thinks they have different personalities"  2
#  2           "that the personalities do not match"  3
#  3                                "not getting on"  0
#
#                                                     7 q7  \
#  0  "Yes they also want to break up so they dont h...  2
#  1                  "yes if he  is going to bore her"  3
#  2    "yes, they dont want to keep boring the person"  3
#  3               "no, didnt think anything was wrong"  0
#
#                                                     8 q8
#  0  "Jessie wants the philosophy books back that s...  3
#  1                                           "Jessie"  1
#  2            "jessie wants her philosphy books back"  3
#  3                                           "calvin"  0
#
#  [4 rows x 21 columns],
#           date               prolific_id  story  persp  p_type  \
#  0  2020-07-30  5bf18310fb616800014fd2dd     13      3       0
#  1  2020-07-30  5eb5dafddac6754c4ee9d0d7     13      3       1
#  2  2020-07-30  5eaa0e5b3b32cf1b13880d65     13      3       0
#
#                                           1  q1                             2  \
#  0                                 " quiet"   0                       "pasta"
#  1  "smells like lavender and is dimly lit"   2  "pasta, vodka sauce, olives"
#  2            "normal and not too crowded."   0                       "pasta"
#
#     q2                                                  3  ...  \
#  0   0                                                "1"  ...
#  1   3  "1 checkout lane is open, the clients step int...  ...
#  2   0  "just one was available and lane 2 to be speci...  ...
#
#                                                     4 q4  \
#  0                                  "Emmanuella paid"  0
#  1  "groceries cost 30 dollars and paid with credi...  3
#  2         "30 dollars and she used her credit card."  3
#
#                                                     5 q5  \
#  0                                           "months"  0
#  1                                        " 5 months"  3
#  2  "for a while  now emanuella has been thinking ...  0
#
#                                                     6 q6  \
#  0                                   "fight too much"  1
#  1                                 "arguing too much"  0
#  2  "she does not get enough attention and help fr...  0
#
#                                                     7 q7  \
#  0     "Yes, they would be happier with other people"  3
#  1               "yes he thinks they will be happier"  2
#  2  "yes they both agreed to break up, if it will ...  2
#
#                             8 q8
#  0  "Liam wants his cat back"  3
#  1      "liam wanted the cat"  3
#  2      "liam wants the cat."  3
#
#  [3 rows x 21 columns],
#           date               prolific_id  story  persp  p_type  \
#  0  2020-07-30  55a43687fdf99b7da1908e0f     14      4       0
#  1  2020-07-30  59dc458f77860e000151240e     14      4       1
#  2  2020-07-30  5b1386089663ee0001461b6e     14      4       0
#  3  2020-07-30  5e90781c06c6ee000974d087     14     10       2
#
#                                                     1  q1  \
#  0                                            "large"   1
#  1         "The lecture hall is large and spacious. "   1
#  2  "Do not remember.  I think there was something...   0
#  3      "A stage at the front with 15 tiers of seats"   2
#
#                                                     2  q2  \
#  0                                     "anthropology"   0
#  1  "The students are in a philosophy class and th...   0
#  2      "I think it was Aristotle, about categories."   1
#  3        "Philosophy to do categories of some sort?"   1
#
#                                                     3  ...  \
#  0                                       "aristoltle"  ...
#  1  "Concepts from ancient Greeks and the history ...  ...
#  2                                      "Philosophy."  ...
#  3                                      "Aristoltle?"  ...
#
#                                                     4 q4  \
#  0                                   "exam next week"  2
#  1  "They had to write a paper on the Socratic met...  0
#  2                                  "Do not remember"  0
#  3                   "They have an exam next tuesday"  3
#
#                                                     5 q5  \
#  0                                           " weeks"  0
#  1  " Maria had been thinking about breaking up fo...  0
#  2                                 " Do not remember"  0
#  3  " For a while, probobaly since she got confirm...  0
#
#                                                     6 q6  \
#  0            "she did not want to do long distance."  3
#  1  "Maria was going to be traveling abroad and di...  1
#  2    "She could not do a long distance relationship"  3
#  3  "She is moving away to study abroad and doesna...  3
#
#                                                     7 q7  \
#  0                               "no, they love her,"  3
#  1  "No, Henry does not want to break up because h...  3
#  2                                               "No"  2
#  3                             "No, they love Maria."  3
#
#                                                     8 q8
#  0                                            "maria"  1
#  1  "Maria wants her favorite alpaca sweater back ...  3
#  2                                            "Maria"  1
#  3  "Maria wants her alpacca sweater from Henryapo...  3
#
#  [4 rows x 21 columns],
#           date               prolific_id  story  persp  p_type  \
#  0  2020-07-30  5e7009d7b3d2255e174696cd     21      1       1
#  1  2020-07-30  5cd0ca0e657e300001945935     21     20       2
#  2  2020-07-30  561fb820ed6e5a000fc7ec68     21     20       2
#  3  2020-07-30  5d03b5abd95b760017c46e18     21      1       1
#  4  2020-07-30  5e9d13e59fb53d1f274065cb     21      1       0
#
#                                                     1  q1  \
#  0                                 " it is beautiful"   0
#  1                               " with chandeliers "   1
#  2  "chandeliers and views of the ocean.Sounded ve...   2
#  3        " With chandeliers and a view of the ocean"   2
#  4  " the restaurant has a great view of the ocean...   2
#
#                                                     2  q2  \
#  0                      "small with swirling writing"   2
#  1                   "small  with chefs descriptions"   2
#  2  "Small menus with selections from the head che...   3
#  3  "small with cursive loop writing and no mentio...   3
#  4                        "oysters, some cake and ??"   0
#
#                                               3  ...  \
#  0                  "oysters with garlic sauce"  ...
#  1                                          NaN  ...
#  2  "Senna had oysters and Alvira had scallops"  ...
#  3                          "oysters and pasta"  ...
#  4                  "some oysters and sea food"  ...
#
#                                                     4 q4                     5  \
#  0                                        "very much"  1             "5 years"
#  1                                       "delicious "  1             "5 years"
#  2  "They loved it, the oysters tasted like the oc...  3            " 5 years"
#  3  "Very much Sennaapostrophes oysters were parti...  3             "5 years"
#  4  "Yes, they loved it cos the oyster, especially...  3  "5 years...not sure"
#
#    q5                                                  6 q6  \
#  0  3                                         "3 yellow"  2
#  1  3                              "3 x yellow diamonds"  2
#  2  3  "3 canary yellow diamonds from his Grandmaapos...  3
#  3  3                              "3 and canary yellow"  3
#  4  3                                 "3 white diamonds"  1
#
#                        7 q7             8 q8
#  0      "chocolate cake"  3         "dad"  3
#  1        "a small cake"  3         "dad"  3
#  2        "A small cake"  3     "Her dad"  3
#  3  "in a box on a cake"  2     "Her dad"  3
#  4                "cake"  3  "Her father"  3
#
#  [5 rows x 21 columns],
#           date               prolific_id  story  persp  p_type  \
#  0  2020-07-30  5dd827c1393bd37c1adb1d47     22      2       1
#  1  2020-07-30  5898b6e256357700011c2c6b     22     20       2
#  2  2020-07-30  5a68460063394a000155bc50     22     20       2
#  3  2020-07-30  5c6fe83f2b44fc000115f3b9     22      2       0
#  4  2020-07-30  5ec607a0e89daa67ea37f84f     22      2       0
#
#                       1  q1                                     2  q2  \
#  0  "1 hour 15 minutes"   3  "someone with metal on their person"   3
#  1             "30 min"   0                      "ring in pocket"   0
#  2            "no idea"   0        "isabel had packed her laptop"   0
#  3                  "?"   0     "ring setting of metal detectors"   0
#  4              "hours"   0                        "the proposal"   0
#
#                         3  ...                           4 q4  \
#  0                   "c4"  ...                        "5a"  0
#  1                   "34"  ...               "first claww"  1
#  2              "no idea"  ...  "first class front seats "  1
#  3  "donapostrophet know"  ...                 "dont know"  0
#  4        "boarding gate"  ...                     "2a 2b"  2
#
#                     5 q5            6 q6                7 q7  \
#  0          " 1 year"  0     "3 pink"  2            "box"  1
#  1               " 2"  0          "1"  0        "red bag"  1
#  2       " 11 months"  3    "no idea"  0  "a velvet case"  1
#  3  " I have no idea"  0  "1 i think"  0     "a ring box"  1
#  4              " 5 "  0         "10"  0        "propose"  0
#
#                     8 q8
#  0       "her friend"  2
#  1            "no on"  0
#  2  "her best friend"  3
#  3    "cant remember"  0
#  4             "love"  0
#
#  [5 rows x 21 columns],
#           date               prolific_id  story  persp  p_type  \
#  0  2020-07-30  56a8bb427f2472000b9522f6     23     20       2
#  1  2020-07-30  5ebf19feee7c5b13537f1d35     23      3       1
#  2  2020-07-30  5dc486da84799a35fbede98d     23      3       1
#  3  2020-07-30  5b9d57e5737d030001ad2cbf     23      3       0
#  4  2020-07-30  5ec1908afa6533211eb93144     23     20       2
#  5  2020-07-30  558acd52fdf99b65685f03d9     23      3       1
#
#                                                     1  q1  \
#  0  " busy because it is nearing thanksgiving. the...   1
#  1                                         "bustling"   0
#  2  " bright and spacious busy as it is thanksgiving"   1
#  3                               " I cannot remember"   0
#  4       "Packed with people because of Thanksgiving"   0
#  5  " cluttered with posters in the front. a lot o...   1
#
#                                                     2  q2  \
#  0  "pumpkin puree and vinegar. they bought other ...   3
#  1                                            "bread"   0
#  2                        "cranberry sauce chestnuts"   0
#  3                   "tinned pumpkin and cranberries"   1
#  4                                       "groceries "   0
#  5                             "Turkeys and stuffing"   0
#
#                                                     3  ...  \
#  0  "3 open and they went to one nearest the entra...  ...
#  1                       "5 are open, they went to 3"  ...
#  2                                      "checkout 3 "  ...
#  3                             "5 and they went to 2"  ...
#  4                             "3 lanes, second one."  ...
#  5                     "Two and the one on the left."  ...
#
#                                                     4 q4             5 q5  \
#  0                                 "14 dollars. cash"  3   "23 months"  3
#  1                         "14 dollars, paid in cash"  3    " 3 years"  0
#  2                                  "14 dollars cash"  3   "23 months"  3
#  3                                  "14 paid by cash"  3   "21 months"  0
#  4                               "$14. Paid in cash."  3  " 24 months"  0
#  5  "$55 and someone paid for them with a credit c...  0    "26 weeks"  0
#
#                                                     6 q6                    7  \
#  0  "white and multiple diamonds. sparkly and dazz...  2             "wallet"
#  1                                      "5 and white"  2           "ring box"
#  2                                  "1 white diamind"  3               "yams"
#  3                                  "1 white diamond"  3  "inside his wallet"
#  4                    "2 diamonds and glittery white"  2             "wallet"
#  5                             "1 diamond, and white"  3      "a crusted box"
#
#    q7                  8 q8
#  0  3           "mother"  3
#  1  0          "her mom"  3
#  2  0              "mum"  3
#  3  3  "cannot remember"  0
#  4  3           "mother"  3
#  5  0          "her mom"  3
#
#  [6 rows x 21 columns],
#           date               prolific_id  story  persp  p_type  \
#  0  2020-07-30  5772908d908f1d0001c38893     24      4       0
#  1  2020-07-30  5ed1443918f6bd07449d88a5     24      4       1
#  2  2020-07-30  5eca8de81197051fa92b5a6a     24      4       0
#  3  2020-07-30  5c1d234d89f035000172aeb7     24      4       1
#  4  2020-07-30  5bd5a2bd9afb5b00015c8f46     24      4       0
#  5  2020-07-30  5b200bbd325d600001c041c0     24      4       0
#
#                                                     1  q1  \
#  0                                   " large and old"   0
#  1                                                NaN   0
#  2  "it is the nicest lecture hall on campus. it h...   1
#  3   " the fanciest lecture hall in all of princeton"   1
#  4                                  " large and airy"   0
#  5                                    "old and large"   0
#
#                           2  q2  \
#  0              "chemistry"   1
#  1                      NaN   0
#  2        "Chemistry; ions"   2
#  3  "chemistry, about ions"   2
#  4    "chem class about na"   1
#  5    "chemistry, elements"   1
#
#                                                     3  ...  \
#  0                             "something about ions"  ...
#  1                                                NaN  ...
#  2  "the number of electrons in the nucleus can de...  ...
#  3                 "the distinction between elements"  ...
#  4                          "something about protons"  ...
#  5                                     "the elements"  ...
#
#                                                     4 q4              5 q5  \
#  0                                   "test next week"  2    "dont know"  0
#  1                                                NaN  0            " "  0
#  2  "a midterm test on the material from the first...  3      "2 years"  0
#  3  "an exam next monday on the last three weeks o...  3  "three years"  3
#  4                                        "dont know"  0      "3 years"  3
#  5                              "elements, next week"  1     " 3 years"  3
#
#                     6 q6                            7 q7                8 q8
#  0        "dont know"  0                  "dont know"  0        "friends"  0
#  1                NaN  0                          NaN  0              NaN  0
#  2   "5 red diamonds"  3  "a sheet of notebook paper"  3         "sister"  3
#  3  "five red jewels"  3                 "a notebook"  3     "her sister"  3
#  4            "5 red"  3                   "notebook"  3         "sister"  3
#  5            "5 red"  3                       "band"  0  "i got engaged"  0
#
#  [6 rows x 21 columns],
#           date               prolific_id  story  persp  p_type  \
#  0  2020-07-30  58df90cecc6d9800018c5d58     31      1       0
#  1  2020-07-30  5e177578fd7db4082cf06d91     31     30       2
#  2  2020-07-30  57843b986475d400015a8e45     31      1       0
#  3  2020-07-30  5d7036ba34c25f0019dc23e8     31      1       1
#  4  2020-07-30  5e58333d4b439f04b1069026     31     30       2
#  5  2020-07-30  5c2bbcc63ea0310001d7257e     31      1       1
#
#                                                     1  q1  \
#  0  " I cant remember at all hearing anything abou...   0
#  1                                "with animal heads"   1
#  2                                                NaN   0
#  3  " dark wooden panelling with taxidermy on the ...   2
#  4                               "Taxidermy and wood"   2
#  5                        " they are in a red lobby "   0
#
#                                2  q2  \
#  0         "heavy and have felt"   2
#  1            "felted and heavy"   2
#  2               "Premium meals"   0
#  3           "heavy and velvety"   2
#  4             "Thick and heavy"   1
#  5  "the menus are quite fancy "   0
#
#                                                     3  ...  \
#  0          "some meat and one of them has a martini"  ...
#  1                                            "steak"  ...
#  2                               "Manhattan and Veal"  ...
#  3  "steak and martini, and I cannot remember the ...  ...
#  4                  "One has veal, the other a steak"  ...
#  5            "some meat ,i think steak and a drink "  ...
#
#                                                     4 q4  \
#  0              "they dont like it. the meat is dry "  2
#  1                                      "medium rare"  0
#  2                 "They find it to be underwhelming"  1
#  3  "They thought they were sub par.  Not really t...  1
#  4  "Not pleased, the meat was overcooked and too ...  3
#  5  "they thought the food was subpar and the meat...  2
#
#                                                     5 q5  \
#  0  "one of them owns a business, cant remember th...  1
#  1                                     " CEO and CFO"  2
#  2                                             " Ceo"  1
#  3                                              "CEO"  1
#  4                               " Company directors"  1
#  5                   "business managers of directors"  1
#
#                             6 q6                    7 q7  \
#  0            "cant remember"  0      "cant remember"  0
#  1                "9million "  1                  "?"  0
#  2                        NaN  0                  NaN  0
#  3  "num_6num_0num_0 million"  2  "I do not remember"  0
#  4                    "$600m"  3           "Jet Tech"  2
#  5                        NaN  0                  NaN  0
#
#                                     8 q8
#  0                          "a toast"  2
#  1                   "Clink martinis"  3
#  2                      "shake hands"  0
#  3              "clink their glasses"  3
#  4                          "A toast"  2
#  5  "clinking there glasses togather"  3
#
#  [6 rows x 21 columns],
#           date               prolific_id  story  persp  p_type  \
#  0  2020-07-30  5c730ca1f674750001df8d09     32      2       0
#  1  2020-07-30  5ae5e66d3ab2fb0001ef2f3c     32      2       1
#  2  2020-07-30  59a817a969b7e70001fe5d38     32      2       0
#  3  2020-07-30  5ed478fa7d20a043b7c3be83     32      2       1
#
#                                                     1  q1  \
#  0  " I dont remember, but they were certainly sho...   0
#  1                                         " 2 hours"   3
#  2                                       "40 minutes"   0
#  3                                      " 30 minutes"   0
#
#                                                  2  q2              3  ...  \
#  0                     "bins were being rolled in"   3  "I am unsure"  ...
#  1                                  "lack of bins"   0           "8b"  ...
#  2                                   "i dont know"   0        "north"  ...
#  3  "to roll out empty bins to put their items in"   3     "not sure"  ...
#
#                                                     4 q4  \
#  0  "Jeff sits in business class, although i dont ...  2
#  1                                    "front section"  0
#  2                                      "i dont know"  0
#  3  "jeff was business class seat 4a william you n...  3
#
#                                                     5 q5              6 q6  \
#  0                         "Wine Product Consultant?"  0  "I dont know"  0
#  1  "east coast supplier of wines, purchaser of wi...  1         "$800"  3
#  2                         " ceo at the wine company"  0         "5000"  0
#  3  "jeff worked at a winery as a seller william w...  2         "$800"  3
#
#                     7 q7                8 q8
#  0    "Cant remember"  0  "Dont remember"  0
#  1     "yankee vines"  3     "hand shake"  3
#  2  "i cant remember"  0         "thanks"  0
#  3  "do not remember"  0      "handshake"  3
#
#  [4 rows x 21 columns],
#           date               prolific_id  story  persp  p_type  \
#  0  2020-07-30  5ea5bee3fc11ed5a8a85f26b     33      3       0
#  1  2020-07-30  5eb3c2e29eb7cb1a6d8054bc     33      3       1
#  2  2020-07-30  5460ef52fdf99b49ea4b5906     33      3       1
#  3  2020-07-30  5ac607f668b65b00018d60fa     33     30       2
#  4  2020-07-30  5ebee71b8565892a3d0b5053     33      3       0
#  5  2020-07-30  5e66af6f70f23a07c791f77d     33      3       1
#  6  2020-07-30  5ea201ca3a942a102c3bb83a     33     30       2
#
#                                                     1  q1  \
#  0                      " big store with many asiles"   0
#  1                   "busy with pumpkins on one side"   1
#  2         " it had halloween displays with pumpkins"   2
#  3                            "dressed for halloween"   1
#  4  " it has halloween decorations and items and i...   1
#  5                        "fresh produce at entrance"   0
#  6                           " stocked for halloween"   1
#
#                                                     2  q2  \
#  0           "crackers, ketchup, and sparkling water"   3
#  1                         "crackers and fizzy water"   2
#  2                        "crackers, sparkling water"   2
#  3              "crackers, ketchup and bottled water"   2
#  4  "they pick out crackers, ketchup and sparkling...   3
#  5                                         "crackers"   1
#  6               "crackers, ketchup, sparkling water"   3
#
#                                         3  ...  \
#  0             "10, they went to asile 6"  ...
#  1                       "10 open lane 6"  ...
#  2                       "lane 6, 4 open"  ...
#  3                                "10, 6"  ...
#  4  "10 are open and they go to number 6"  ...
#  5        "10 open they step into lane 6"  ...
#  6                   "10 aisles, aisle 6"  ...
#
#                                                     4 q4  \
#  0                           "23 dollars, with check"  3
#  1                            "23 dollars and cheque"  3
#  2                               "23 dollars, cheque"  3
#  3                               "23 dollars, cheque"  3
#  4  "the groceries cost $23 and ms morrison uses a...  3
#  5                                           "cheque"  3
#  6                                      "$23, cheque"  3
#
#                                                     5 q5  \
#  0                          "manager and sales agent"  1
#  1  "head of purchasing and sales for an italian c...  1
#  2          "cheese salesperson, supermarket manager"  1
#  3                            " sales representative"  1
#  4                                  "do not remember"  0
#  5   " national sales manager and purchasing manager"  1
#  6                                                "."  0
#
#                             6 q6                      7 q7  \
#  0             "1500 dollars"  3        "orange fields"  2
#  1                    "12000"  0   "orange supermarket"  2
#  2  "50,000 dollarsbackslash"  0     "orange groceries"  3
#  3                     "1500"  3       "orange grocers"  3
#  4                   "$20000"  0  "orange supermarkets"  2
#  5                     "1500"  3            "Dont know"  0
#  6                    "$1500"  3         "orange grove"  2
#
#                                                     8 q8
#  0                                  "drink champagne"  3
#  1                                        "handshake"  0
#  2                                   "mini champagne"  3
#  3                            "a bottle of champagne"  3
#  4  "thy pop open a small bottle of champagne that...  3
#  5                                "popping champange"  3
#  6                                    "pop champagne"  3
#
#  [7 rows x 21 columns],
#           date               prolific_id  story  persp  p_type  \
#  0  2020-07-30  5cdad620eae6f70019d4e950     34      4       1
#  1  2020-07-30  5caa2d8967451a0015304067     34     30       2
#  2  2020-07-30  58d9a79c33fef3000118abdf     34      4       1
#  3  2020-07-30  59feed1da383a100011b3eaa     34      4       1
#  4  2020-07-30  5d0114857be13b0016e991c3     34     30       2
#
#                                                     1  q1  \
#  0            "big with lots of outlets for charging"   1
#  1                                       " no idea! "   0
#  2  " It was wide with electrical outlets for the ...   1
#  3                     " it is large with projectors"   1
#  4                                  "dark and narrow"   0
#
#                                                     2  q2  \
#  0                                          "history"   0
#  1                                "Greeceslashromans"   0
#  2  "Archaeology, the lecture was about Augustus i...   3
#  3  "It is about Roman architecture in the era of ...   2
#  4                                                NaN   0
#
#                                                     3  ...  \
#  0                                  "I cant recall. "  ...
#  1                                          "no idea"  ...
#  2                 "What Augustus has done for Rome."  ...
#  3  "Augustus wanted to transform Rome into the ne...  ...
#  4                                         "not sure"  ...
#
#                                                     4 q4  \
#  0                      "Write a paper of some kind."  1
#  1                                          "no idea"  0
#  2                     "It was the midterms tomorrow"  1
#  3  "the midterm paper is due on thursday and shou...  3
#  4                                        "next week"  0
#
#                                                     5 q5  \
#  0  " Alma started the company. Charlie is on a fi...  1
#  1                                    "alma was ceo?"  1
#  2                       "Investor and web developer"  1
#  3  "Charlie is a fund manager for a campus invest...  2
#  4                                  " web developers"  0
#
#                                   6 q6                               7 q7  \
#  0                          "25000"  2  "Churchill group or something"  2
#  1  "28000 offered then full 56000"  3                     "churchill"  2
#  2                          "52000"  0                           "Don"  0
#  3                         "$28000"  3                     "Churchill"  2
#  4                         "100000"  0                      "not sure"  0
#
#                    8 q8
#  0       "handshake"  0
#  1          "hugged"  3
#  2     "They hugged"  3
#  3           "a hug"  3
#  4  "shake of hands"  0
#
#  [5 rows x 21 columns],
#           date               prolific_id  story  persp  p_type  \
#  0  2020-07-30  5ebd841ddea21b08a0aa3057     41      1       0
#  1  2020-07-30  5e8b357c8d6ecf023440f7ea     41      1       1
#  2  2020-07-30  5ac033fa68b65b00018d2c1a     41      1       0
#
#                                                     1  q1  \
#  0  "The restaurant was decorated with wood panels...   1
#  1                           "foliage, tall ceilings"   1
#  2                          "I donapostrophet recall"   0
#
#                                                     2  q2  \
#  0  "The menus were in bright colors and the menu ...   2
#  1  "neon with japanese text in large and small en...   3
#  2                          "I donapostrophet recall"   0
#
#                                                     3  ...  \
#  0  "James ordered a tuna roll and vegetable roll....  ...
#  1                            "salmon roll and drink"  ...
#  2  "she orders a fish roll with a beer, he orders...  ...
#
#                                           4 q4                   5 q5  \
#  0                                      "I"  0      " a newspaper"  3
#  1                                  "a lot"  1           "a phone"  0
#  2  "quite a lot because the fish is fresh"  3  " I do not recall"  0
#
#                            6 q6                                         7 q7  \
#  0  "Is your forehead okay?"  3  "They will meet at an Egyptian concert."  1
#  1         "is your head ok"  2                              "for a date"  0
#  2            "Did it hurt?"  0                    "The egyptian concert"  2
#
#                 8 q8
#  0  "It was 3pm."  3
#  1           "3 "  3
#  2            "3"  3
#
#  [3 rows x 21 columns],
#           date               prolific_id  story  persp  p_type  \
#  0  2020-07-30  5ea9cf685ce96d13164b381a     42      2       0
#  1  2020-07-30  5eb3d22ffa15221c2e0117c5     42      2       1
#  2  2020-07-30  5c8ebaed13e167000176428f     42      2       1
#
#                                         1  q1  \
#  0                           "20 minutes"   0
#  1                          "30 minutes?"   0
#  2  " David has 3 hours and Anna 35 mins"   3
#
#                                       2  q2         3  ...              4 q4  \
#  0                               "line"   0  "gate b"  ...           "17"  0
#  1      "the metal detector was broken"   3      "c?"  ...  "first class"  0
#  2  "malfunction of the metal detector"   3     "j37"  ...  "7D business"  3
#
#                  5 q5                     6 q6                          7 q7  \
#  0     " suitcase"  0  "were you a gymnist"  3             "next tuesday"  2
#  1     " suitcase"  0        "how are you?"  0                  "wedding"  0
#  2  "luggage cart"  0  "are you a gymnast?"  3  "next tuesday for drinks"  2
#
#                                          8 q8
#  0                              "10:55 am"  3
#  1                                 "10pm?"  0
#  2  "5 minutes before her flight leaves.."  0
#
#  [3 rows x 21 columns],
#           date               prolific_id  story  persp  p_type  \
#  0  2020-07-30  5ec2d656c999700e29f63932     43      3       0
#  1  2020-07-30  5d6aad2a9c753300019d9f80     43     40       2
#  2  2020-07-30  5c9e773a9ab9320001fbe51c     43      3       0
#  3  2020-07-30  5b12b0651e55760001b9ed8c     43      3       1
#  4  2020-07-30  5ea5b32f7e4bd55a4a53f0d6     43      3       1
#
#                                                     1  q1  \
#  0  " Large and unlike something they had seen bef...   0
#  1                                             "busy"   0
#  2                                  "large warehouse"   1
#  3  " it was a big warehouse with tall black ceili...   3
#  4                         " It was clean and tidy? "   0
#
#                                                     2  q2  \
#  0                                  "Meat and kebabs"   0
#  1                                 "peppers and meat"   1
#  2                            "ribs, peppers, spices"   2
#  3                "ribs and vegetables, and bbq food"   1
#  4  "Items to prepare barbeque such as fresh meat ...   0
#
#                                                     3  ...  \
#  0  "Three were open and they stepped into the third"  ...
#  1                               "2 lanes and lane 2"  ...
#  2                                             "pass"  ...
#  3                                               "8 "  ...
#  4  "client pick up lane no 8 and I believe 9 lane...  ...
#
#                                                     4 q4                     5  \
#  0               "$52 and Simon used his credit card"  3  "The frozen chicken"
#  1            "54 dollars and he pays by credit card"  3               " keys"
#  2                          "$54, Simon pays on card"  3            " chicken"
#  3                           "$52 and a credit card "  3          "their keys"
#  4  "payment was made through card but not sure ab...  2                "meat"
#
#    q5                                6 q6                      7 q7  \
#  0  0  "The chicken is large isnt it?"  0  "Saturday for a date"  2
#  1  3       "Does that meat look cute"  2  "saturday for a date"  2
#  2  0                           "pass"  0                 "date"  0
#  3  3                       "not sure"  0        "a dinner date"  1
#  4  0           "If meat looks fresh "  2            "for date?"  0
#
#                    8 q8
#  0          "Half 4"  3
#  1             "4pm"  2
#  2          "4.30pm"  3
#  3           "4:30 "  3
#  4  "not remembered"  0
#
#  [5 rows x 21 columns],
#           date               prolific_id  story  persp  p_type  \
#  0  2020-07-30  5ea95301f1853405e031a30d     44     40       2
#  1  2020-07-30  59de4ee5d838ae0001850567     44      4       1
#  2  2020-07-30  5d5db7f7ca179000180b17cc     44      4       0
#
#                                             1  q1  \
#  0                                        " "   0
#  1  " It was dark as it was in the basement."   0
#  2                                  "history"   0
#
#                                    2  q2  \
#  0  "history of egypt mummification"   3
#  1            "The history of Egypt"   3
#  2          "history, mummification"   2
#
#                                                     3  ...                 4  \
#  0                                                NaN  ...  "quiz on friday"
#  1  "They are talking about the process of mummifi...  ...               "2"
#  2                                "topic about mummy"  ...        "not sure"
#
#    q4           5 q5                         6 q6  \
#  0  2    "eraser"  3         "are you from La"  3
#  1  0     "a pen"  0        "a note from leon"  0
#  2  0  "not sure"  3  "have i seen you before"  0
#
#                                             7 q7                      8 q8
#  0                           "8pm for a walk"  3                 "noon"  3
#  1                  "that evening for a date"  1  "cant remember sorry"  0
#  2  "they will meet later tonight for coffee"  1                  "4pm"  0
#
#  [3 rows x 21 columns]]

# %%
# checking to make sure no weird formatting

# ROUND 1 
print('Round 1')
for i in range(0,16):
    print(rs_dfs_al_1[i]['story'].iloc[0])
    print(rs_dfs_tk[i]['story'].iloc[0])
    print(rs_dfs_ar_1[i]['story'].iloc[0])
    print(rs_dfs_t_1[i]['story'].iloc[0])
    print(rs_dfs_e_1[i]['story'].iloc[0])
    print(rs_dfs_al_1[i].shape)
    print(rs_dfs_tk[i].shape)
    print(rs_dfs_ar_1[i].shape)
    print(rs_dfs_t_1[i].shape)
    print(rs_dfs_e_1[i].shape)
    
# ROUND 2
print('Round 2')
for i in range(0,16):
    print(rs_dfs_al_2[i]['story'].iloc[0])
    print(rs_dfs_ar_2[i]['story'].iloc[0])
    print(rs_dfs_t_2[i]['story'].iloc[0])
    print(rs_dfs_e_2[i]['story'].iloc[0])
    print(rs_dfs_al_2[i].shape)
    print(rs_dfs_ar_2[i].shape)
    print(rs_dfs_t_2[i].shape)
    print(rs_dfs_e_2[i].shape)
    
# ROUND 3
print('n\n\nRound 3')
for i in range(0,16):
    print(rs_dfs_al_3[i]['story'].iloc[0])
    print(rs_dfs_ar_3[i]['story'].iloc[0])
    print(rs_dfs_t_3[i]['story'].iloc[0])
    print(rs_dfs_e_3[i]['story'].iloc[0])
    print(rs_dfs_al_3[i].shape)
    print(rs_dfs_ar_3[i].shape)
    print(rs_dfs_t_3[i].shape)
    print(rs_dfs_e_3[i].shape)
# Out:
# Round 1
# 11
# 11
# 11
# 11
# 11
# (3, 29)
# (3, 21)
# (3, 29)
# (3, 21)
# (3, 21)
# 12
# 12
# 12
# 12
# 12
# (5, 29)
# (5, 21)
# (5, 29)
# (5, 21)
# (5, 21)
# 13
# 13
# 13
# 13
# 13
# (2, 29)
# (2, 21)
# (2, 29)
# (2, 21)
# (2, 21)
# 14
# 14
# 14
# 14
# 14
# (5, 29)
# (5, 21)
# (5, 29)
# (5, 21)
# (5, 21)
# 21
# 21
# 21
# 21
# 21
# (3, 29)
# (3, 21)
# (3, 29)
# (3, 21)
# (3, 21)
# 22
# 22
# 22
# 22
# 22
# (6, 29)
# (6, 21)
# (6, 29)
# (6, 21)
# (6, 21)
# 23
# 23
# 23
# 23
# 23
# (7, 29)
# (7, 21)
# (7, 29)
# (7, 21)
# (7, 21)
# 24
# 24
# 24
# 24
# 24
# (4, 29)
# (4, 21)
# (4, 29)
# (4, 21)
# (4, 21)
# 31
# 31
# 31
# 31
# 31
# (2, 29)
# (2, 21)
# (2, 29)
# (2, 21)
# (2, 21)
# 32
# 32
# 32
# 32
# 32
# (4, 29)
# (4, 21)
# (4, 29)
# (4, 21)
# (4, 21)
# 33
# 33
# 33
# 33
# 33
# (6, 29)
# (6, 21)
# (6, 29)
# (6, 21)
# (6, 21)
# 34
# 34
# 34
# 34
# 34
# (4, 29)
# (4, 21)
# (4, 29)
# (4, 21)
# (4, 21)
# 41
# 41
# 41
# 41
# 41
# (1, 29)
# (1, 21)
# (1, 29)
# (1, 21)
# (1, 21)
# 42
# 42
# 42
# 42
# 42
# (6, 29)
# (6, 21)
# (6, 29)
# (6, 21)
# (6, 21)
# 43
# 43
# 43
# 43
# 43
# (5, 29)
# (5, 21)
# (5, 29)
# (5, 21)
# (5, 21)
# 44
# 44
# 44
# 44
# 44
# (4, 29)
# (4, 22)
# (4, 29)
# (4, 21)
# (4, 21)
# Round 2
# 11
# 11
# 11
# 11
# (7, 21)
# (7, 21)
# (7, 21)
# (7, 21)
# 12
# 12
# 12
# 12
# (4, 21)
# (4, 21)
# (4, 21)
# (4, 21)
# 13
# 13
# 13
# 13
# (3, 21)
# (3, 21)
# (3, 21)
# (3, 21)
# 14
# 14
# 14
# 14
# (4, 21)
# (4, 21)
# (4, 21)
# (4, 21)
# 21
# 21
# 21
# 21
# (5, 21)
# (5, 21)
# (5, 21)
# (5, 21)
# 22
# 22
# 22
# 22
# (5, 21)
# (5, 21)
# (5, 21)
# (5, 21)
# 23
# 23
# 23
# 23
# (6, 21)
# (6, 21)
# (6, 21)
# (6, 21)
# 24
# 24
# 24
# 24
# (6, 21)
# (6, 21)
# (6, 21)
# (6, 21)
# 31
# 31
# 31
# 31
# (6, 21)
# (6, 21)
# (6, 21)
# (6, 21)
# 32
# 32
# 32
# 32
# (4, 21)
# (4, 21)
# (4, 21)
# (4, 21)
# 33
# 33
# 33
# 33
# (7, 21)
# (7, 21)
# (7, 21)
# (7, 21)
# 34
# 34
# 34
# 34
# (5, 21)
# (5, 21)
# (5, 21)
# (5, 21)
# 41
# 41
# 41
# 41
# (3, 21)
# (3, 21)
# (3, 21)
# (3, 21)
# 42
# 42
# 42
# 42
# (3, 21)
# (3, 21)
# (3, 21)
# (3, 21)
# 43
# 43
# 43
# 43
# (5, 21)
# (5, 21)
# (5, 21)
# (5, 21)
# 44
# 44
# 44
# 44
# (3, 21)
# (3, 21)
# (3, 21)
# (3, 21)
# n
#
# Round 3
# 11
# 11
# 11
# 11
# (20, 21)
# (20, 21)
# (20, 21)
# (20, 21)
# 12
# 12
# 12
# 12
# (20, 21)
# (20, 21)
# (20, 21)
# (20, 21)
# 13
# 13
# 13
# 13
# (21, 21)
# (21, 21)
# (21, 21)
# (21, 21)
# 14
# 14
# 14
# 14
# (14, 21)
# (14, 21)
# (14, 21)
# (14, 21)
# 21
# 21
# 21
# 21
# (15, 21)
# (15, 21)
# (15, 21)
# (15, 21)
# 22
# 22
# 22
# 22
# (18, 21)
# (18, 21)
# (18, 21)
# (18, 21)
# 23
# 23
# 23
# 23
# (11, 21)
# (11, 21)
# (11, 21)
# (11, 21)
# 24
# 24
# 24
# 24
# (12, 21)
# (12, 21)
# (12, 21)
# (12, 21)
# 31
# 31
# 31
# 31
# (13, 21)
# (13, 21)
# (13, 21)
# (13, 21)
# 32
# 32
# 32
# 32
# (19, 21)
# (19, 21)
# (19, 21)
# (19, 21)
# 33
# 33
# 33
# 33
# (12, 21)
# (12, 21)
# (12, 21)
# (12, 21)
# 34
# 34
# 34
# 34
# (12, 21)
# (12, 21)
# (12, 21)
# (12, 21)
# 41
# 41
# 41
# 41
# (19, 21)
# (19, 21)
# (19, 21)
# (19, 21)
# 42
# 42
# 42
# 42
# (15, 21)
# (15, 21)
# (15, 21)
# (15, 21)
# 43
# 43
# 43
# 43
# (11, 21)
# (11, 21)
# (11, 21)
# (11, 21)
# 44
# 44
# 44
# 44
# (14, 21)
# (14, 21)
# (14, 21)
# (14, 21)

# %%
rs_dfs_t_1[]
# Out:
#   File "<ipython-input-5-c89a22a64c4f>", line 1
#     rs_dfs_t_1[]
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# # II. Averaging Score of each entry across scorers

# %%
avg_ss = {}
q = ['q1', 'q2', 'q3', 'q4', 'q5', 'q6', 'q7', 'q8']

for i in range(0, 16):
    # Getting the shape of Round 1 score sheets
    x1, y1 = rs_dfs_ar_1[i].shape
    
    # Getting the shape of Round 2 score sheets
    x2, y2 = rs_dfs_ar_2[i].shape
    
    # Getting the shape of Round 3 score sheets
    x3, y3 = rs_dfs_ar_3[i].shape
    
    # Getting the story 
    this_story = rs_dfs_ar_1[i]['story'].iloc[0]
    
    # Making and padding the story column for new df
    story_col = np.array([this_story])
    story_col = np.pad(story_col, (0, ((x1 + x2 + x3)-1)), mode = 'constant')
    
    #making the prolific id column
    id_col_1 = rs_dfs_ar_1[i]['prolific_id']
    id_col_2 = rs_dfs_ar_2[i]['prolific_id']
    id_col_3 = rs_dfs_ar_3[i]['prolific_id']
    id_col = pd.concat([id_col_1, id_col_2, id_col_3])
    
    #making the perspective column
    persp_col_1 = rs_dfs_ar_1[i]['persp']
    persp_col_2 = rs_dfs_ar_2[i]['persp']
    persp_col_3 = rs_dfs_ar_3[i]['persp']
    persp_col = pd.concat([persp_col_1, persp_col_2, persp_col_3])
    
    #making the priming-type column
    p_col_1 = rs_dfs_ar_1[i]['p_type']
    p_col_2 = rs_dfs_ar_2[i]['p_type']
    p_col_3 = rs_dfs_ar_3[i]['p_type']
    p_col = pd.concat([p_col_1, p_col_2, p_col_3])
    
    #instantiate df
    data = {'story': story_col,'id': id_col,'perspective': persp_col, 'priming': p_col}
    this_df = pd.DataFrame(data)
    ##Averaging scores across scorers
    for this_q in q:
        # Round 1
        #get each scorers scores for a question
        x = rs_dfs_ar_1[i][this_q]
        y = rs_dfs_tk[i][this_q]
        z = rs_dfs_al_1[i][this_q]
        a = rs_dfs_t_1[i][this_q]
        e = rs_dfs_e_1[i][this_q]
        #put them all in an array
        tog1 = np.array((x, y, z, a,e))
        #avg across the rows
        avg1 = np.nanmean(tog1, axis=0)
        
        # Round 2
        #get each scorers scores for a question
        x2 = rs_dfs_ar_2[i][this_q]
        y2 = rs_dfs_al_2[i][this_q]
        a2 = rs_dfs_t_2[i][this_q]
        e2 = rs_dfs_e_2[i][this_q]
        #put them all in an array
        tog2 = np.array((x2, y2, a2, e2))
        #avg across the rows
        avg2 = np.nanmean(tog2, axis=0)
        
        # Round 3
        #get each scorers scores for a question
        x3 = rs_dfs_ar_3[i][this_q]
        y3 = rs_dfs_al_3[i][this_q]
        a3 = rs_dfs_t_3[i][this_q]
        e3 = rs_dfs_e_3[i][this_q]
        #put them all in an array
        tog3 = np.array((x3, y3, a3, e3))
        #avg across the rows
        avg3 = np.nanmean(tog3, axis=0)
        
        # Concatenate Round 1 and Round 2
        avg = np.concatenate((avg1, avg2, avg3))
        
        #add the avg'd array to this_df
        this_df[this_q] = avg
    #reset the index
    this_df = this_df.reset_index()
    #adding this_df to outstanding dictionary
    avg_ss[this_story] = this_df

# %% [markdown]
# ### Check if there are any avg scores over 3 indicating a scoring typo

# %%
for key in avg_ss:
    for this_q in q:
        if (avg_ss[key][this_q] > 3).any():
            print(key, this_q)

# %% [markdown]
# # III. Naming Excluded Participants
# ###  Exclustion criterion: participant scores 0 for all the answers across all scorers
# ## A. Finding participants to exclude

# %%
for key in avg_ss.keys():
    print('key', key)
    for i in range(0, avg_ss[key].shape[0]):
        count = 0 
        if avg_ss[key]['q1'].iloc[i] == 0:
            count += 1
        else:
            pass
        if avg_ss[key]['q2'].iloc[i] == 0:
            count += 1
        else:
            pass
        if avg_ss[key]['q3'].iloc[i] == 0:
            count += 1
        else:
            pass
        if avg_ss[key]['q4'].iloc[i] == 0:
            count += 1
        else:
            pass
        if avg_ss[key]['q5'].iloc[i] == 0:
            count += 1
        else:
            pass
        if avg_ss[key]['q6'].iloc[i] == 0:
            count += 1
        else:
            pass
        if avg_ss[key]['q7'].iloc[i] == 0:
            count += 1
        else:
            pass
        if avg_ss[key]['q8'].iloc[i] == 0:
            count += 1
        else:
            pass
        if count == 8:
            print(avg_ss[key]['id'].iloc[i])
# Out:
# key 11
# 5f70ae7ad1dae5090b80dbd9
# key 12
# 5ced335ede266200161ea979
# key 13
# key 14
# key 21
# 5e3df34cfb9ed506f1028bb5
# key 22
# 5f670febb29bcb2f7fc96a36
# key 23
# key 24
# 5ed1443918f6bd07449d88a5
# 5f88e4cb07522c0f34faf4b8
# key 31
# key 32
# 5f05d81ae130ca08ee2c73b7
# key 33
# key 34
# 5f0e1c64a3a86a136d884628
# key 41
# key 42
# 5f6aa61123368b1893fd12d6
# 5f5f9b5448f99d01c3b3101e
# 5f970bac28901a06b8152b0b
# key 43
# key 44

# %% [markdown]
# ## B. Manually excluding participants

# %%
avg_ss[11].drop(avg_ss[11].loc[avg_ss[11]['id']=='5f70ae7ad1dae5090b80dbd9'].index, inplace=True)
avg_ss[11].reset_index()

avg_ss[12].drop(avg_ss[12].loc[avg_ss[12]['id']=='5ced335ede266200161ea979'].index, inplace=True)
avg_ss[12].reset_index()

avg_ss[21].drop(avg_ss[21].loc[avg_ss[21]['id']=='5e3df34cfb9ed506f1028bb5'].index, inplace=True)
avg_ss[21].reset_index()

avg_ss[22].drop(avg_ss[22].loc[avg_ss[22]['id']=='5f670febb29bcb2f7fc96a36'].index, inplace=True)
avg_ss[22].reset_index()

avg_ss[24].drop(avg_ss[24].loc[avg_ss[24]['id']=='5ed1443918f6bd07449d88a5'].index, inplace=True)
avg_ss[24].reset_index()

avg_ss[24].drop(avg_ss[24].loc[avg_ss[24]['id']=='5f88e4cb07522c0f34faf4b8'].index, inplace=True)
avg_ss[24].reset_index()

avg_ss[32].drop(avg_ss[32].loc[avg_ss[32]['id']=='59a817a969b7e70001fe5d38'].index, inplace=True)
avg_ss[32].reset_index()

avg_ss[34].drop(avg_ss[34].loc[avg_ss[34]['id']=='5f0e1c64a3a86a136d884628'].index, inplace=True)
avg_ss[34].reset_index()

avg_ss[42].drop(avg_ss[42].loc[avg_ss[42]['id']=='5f6aa61123368b1893fd12d6'].index, inplace=True)
avg_ss[42].reset_index()

avg_ss[42].drop(avg_ss[42].loc[avg_ss[42]['id']=='5f5f9b5448f99d01c3b3101e'].index, inplace=True)
avg_ss[42].reset_index()

avg_ss[42].drop(avg_ss[42].loc[avg_ss[42]['id']=='5f970bac28901a06b8152b0b'].index, inplace=True)
avg_ss[42].reset_index()
# Out:
#     level_0  index  story                        id  perspective  priming  \
# 0         0      0     42  5d82994758861000188f76dc            2        1
# 1         1      1      0  5e3f032709a1141608164346            2        1
# 2         2      2      0  5c8a2d11f7ab04001042af3c           40        2
# 3         3      3      0  5ea945b5692da4020240a251            2        1
# 4         4      4      0  598c282ccceb0f0001b39660            2        0
# 5         5      5      0  562a00dac8ffc20012513fbe            2        1
# 6         6      0      0  5ea9cf685ce96d13164b381a            2        0
# 7         7      1      0  5eb3d22ffa15221c2e0117c5            2        1
# 8         8      2      0  5c8ebaed13e167000176428f            2        1
# 9         9      0      0  5e54309f0a98c705f68ae8a8            2        1
# 10       10      1      0  5a80d4e4f49c9a0001f35cb2            2        1
# 11       11      2      0  5dd9df0e946f7c97406a55ea            2        1
# 12       13      4      0  5f2ef358d45f6110ad8ba935           40        2
# 13       15      6      0  5f8c971713143e0eeebdcd15            2        1
# 14       16      7      0  5dce9f0c867a25197d6944c5           40        2
# 15       17      8      0  5fa48e06e214730d551f1de7            2        0
# 16       18      9      0  5d4dd26210d0030001134f37           40        2
# 17       19     10      0  5f0d6c9bb43cfb0182a9d464            2        0
# 18       20     11      0  55ed87f0748092000baa9a0b            2        0
# 19       21     12      0  5eb1bfe57e59240f9097f59d            2        0
# 20       23     14      0  5b97f8988ae8150001c7a887            2        0
#
#       q1    q2   q3    q4    q5   q6    q7    q8
# 0   0.00  0.00  2.0  2.00  0.00  0.0  2.00  3.00
# 1   2.00  2.40  2.0  2.00  0.00  3.0  2.20  2.00
# 2   1.00  3.00  1.2  0.40  0.00  2.8  3.00  3.00
# 3   0.40  3.00  0.0  1.80  0.00  0.0  2.00  0.00
# 4   1.00  3.00  3.0  1.80  0.00  2.8  3.00  1.20
# 5   1.00  3.00  3.0  3.00  0.00  0.0  0.40  1.60
# 6   0.00  0.00  0.0  0.00  0.00  3.0  2.00  3.00
# 7   0.25  2.75  0.0  0.50  0.75  0.0  0.00  1.00
# 8   3.00  3.00  3.0  3.00  0.00  3.0  2.00  0.50
# 9   0.00  0.00  0.0  2.00  0.00  0.0  2.25  2.25
# 10  0.00  2.25  3.0  0.75  0.00  3.0  3.00  0.00
# 11  0.00  0.00  0.0  0.00  0.00  3.0  0.00  0.00
# 12  0.00  0.00  0.0  0.00  0.00  3.0  1.50  1.25
# 13  0.25  0.00  0.0  1.25  0.00  0.0  0.00  0.00
# 14  2.25  0.00  0.0  0.00  0.00  0.0  0.00  0.00
# 15  1.50  3.00  0.0  0.00  0.00  1.5  2.25  0.00
# 16  2.25  0.00  0.0  0.00  3.00  3.0  3.00  2.75
# 17  0.00  3.00  0.0  0.00  0.00  3.0  1.50  0.00
# 18  2.75  3.00  0.0  0.00  0.00  3.0  1.50  1.50
# 19  2.00  3.00  0.0  2.00  0.00  3.0  2.00  0.00
# 20  0.00  3.00  0.0  2.00  0.00  0.0  2.00  2.00

# %% [markdown]
# # IV. Averaging scores across similarly primed participants
# ## A. Separate priming groups

# %%
ss_0 = {}
ss_1 = {}
ss_2 = {}

for key in avg_ss.keys():
    df_0 = pd.DataFrame(columns=['story','id','perspective','priming','q1','q2','q3','q4','q5','q6','q7','q8'])
    df_1 = pd.DataFrame(columns=['story','id','perspective','priming','q1','q2','q3','q4','q5','q6','q7','q8'])
    df_2 = pd.DataFrame(columns=['story','id','perspective','priming','q1','q2','q3','q4','q5','q6','q7','q8'])
    for i in range(0, avg_ss[key].shape[0]):
        this_row = {'story': avg_ss[key]['story'].iloc[0],
                   'id': avg_ss[key]['id'].iloc[i],
                   'perspective': avg_ss[key]['perspective'].iloc[i],
                   'priming': avg_ss[key]['priming'].iloc[i],
                   'q1': avg_ss[key]['q1'].iloc[i],
                   'q2': avg_ss[key]['q2'].iloc[i],
                   'q3': avg_ss[key]['q3'].iloc[i],
                   'q4': avg_ss[key]['q4'].iloc[i],
                   'q5': avg_ss[key]['q5'].iloc[i],
                   'q6': avg_ss[key]['q6'].iloc[i],
                   'q7': avg_ss[key]['q7'].iloc[i],
                   'q8': avg_ss[key]['q8'].iloc[i]}
        if avg_ss[key]['priming'].iloc[i] == 0:
            df_0 = df_0.append(this_row, ignore_index = True)
        elif avg_ss[key]['priming'].iloc[i] == 1:
            df_1 = df_1.append(this_row, ignore_index = True)
        else:
            df_2 = df_2.append(this_row, ignore_index = True)
    ss_0[key] = df_0
    ss_1[key] = df_1
    ss_2[key] = df_2

# %%
ss_0
# Out:
# {11:    story                        id perspective priming    q1    q2        q3  \
#  0     11  5ea07ccfcc5aed04bc7e4148           1       0  1.60  1.80  1.000000
#  1     11  58af6fa166d1330001eebaab           1       0  1.00  2.80  2.000000
#  2     11  5d6a24c4f186b3001ae5dfeb           1       0  1.00  0.00  2.000000
#  3     11  5d026ba86c626e0019202f6a           1       0  0.75  2.00  1.750000
#  4     11  5ead3fe551c1bb0009b78154           1       0  0.00  0.00  0.000000
#  5     11  5ea611dda778214a5e89fbf2           1       0  1.00  3.00  1.666667
#  6     11  5d305152b2cfe00019231a2a           1       0  1.00  2.00  1.000000
#  7     11  5c3341bc21f99c000175c5cc           1       0  2.25  3.00  3.000000
#  8     11  56b4b565b2de2a000d3316ba           1       0  0.00  3.00  2.000000
#  9     11  5f58fdc20fcd710ce090cdc1           1       0  0.00  0.00  0.000000
#  1    42  5ea9cf685ce96d13164b381a           2       0  0.00  0.0  0.0  0.0
#  2    42  5fa48e06e214730d551f1de7           2       0  1.50  3.0  0.0  0.0
#  3    42  5f0d6c9bb43cfb0182a9d464           2       0  0.00  3.0  0.0  0.0
#  4    42  55ed87f0748092000baa9a0b           2       0  2.75  3.0  0.0  0.0
#  5    42  5eb1bfe57e59240f9097f59d           2       0  2.00  3.0  0.0  2.0
#  6    42  5b97f8988ae8150001c7a887           2       0  0.00  3.0  0.0  2.0
#
#      q5   q6    q7   q8
#  0  0.0  2.8  3.00  1.2
#  1  0.0  3.0  2.00  3.0
#  2  0.0  1.5  2.25  0.0
#  3  0.0  3.0  1.50  0.0
#  4  0.0  3.0  1.50  1.5
#  5  0.0  3.0  2.00  0.0
#  6  0.0  0.0  2.00  2.0  ,
#  43:   story                        id perspective priming    q1    q2   q3    q4  \
#  0    43  5eb2e03e93516108a92d3d96           3       0  1.00  1.20  0.0  3.00
#  1    43  5c12ce5fd3f0d1000108430a           3       0  0.40  0.20  0.0  2.00
#  2    43  5ec2d656c999700e29f63932           3       0  0.75  0.25  1.5  3.00
#  3    43  5c9e773a9ab9320001fbe51c           3       0  1.25  1.75  0.0  2.75
#  4    43  5f68293531178c45eb421365           3       0  0.25  0.25  2.0  2.75
#  5    43  5f52e45ad408d55fa156aa21           3       0  1.00  0.00  3.0  2.75
#  6    43  5d67d4393fcbbc0019f3e1a4           3       0  0.00  0.00  0.0  2.25
#
#      q5    q6    q7   q8
#  0  0.0  2.20  0.40  3.0
#  1  0.0  0.80  0.00  0.2
#  2  0.0  0.50  1.25  3.0
#  3  0.0  0.00  0.00  3.0
#  4  0.0  2.50  1.00  0.0
#  5  0.0  0.00  0.75  3.0
#  6  0.0  2.25  1.50  2.0  ,
#  44:   story                        id perspective priming    q1    q2    q3    q4  \
#  0    44  5c4271f51b4bf300018b0920           4       0  0.00  2.00  0.20  2.80
#  1    44  5cdeaeb3557fbd00018a2c59           4       0  0.00  1.00  0.00  0.00
#  2    44  5d5db7f7ca179000180b17cc           4       0  0.00  1.75  0.50  0.00
#  3    44  5cbbd55510241a0017b81a65           4       0  1.00  2.00  0.75  0.00
#  4    44  5f3aead81965e27c4a531d95           4       0  0.25  2.25  0.25  1.25
#  5    44  5f4a7a00dc1bde60ab8f7ac5           4       0  0.00  1.00  0.25  0.00
#  6    44  55a47692fdf99b126e625257           4       0  0.00  2.00  0.25  1.25
#
#       q5   q6    q7    q8
#  0  3.00  3.0  2.00  0.00
#  1  3.00  3.0  2.20  3.00
#  2  1.50  0.5  0.75  0.00
#  3  2.75  3.0  1.25  2.75
#  4  0.00  3.0  2.25  2.25
#  5  0.00  0.0  0.00  0.00
#  6  0.00  3.0  0.75  0.00  }

# %% [markdown]
# ## B. Average across priming groups and across location and social questions
# ### - output: dict = {avg loc score, avg soc score}

# %%
avg_ss_0 = {}
avg_ss_1 = {}
avg_ss_2 = {}

sss = [ss_0, ss_1, ss_2]
avgs = [avg_ss_0, avg_ss_1, avg_ss_2]

for i in range(0,3):
    print('this is: ', i)
    for key in avg_ss.keys():
        #average column-wise, across all participants for each question
        av_col = sss[i][key].mean(axis = 0)
        #collecting location and social questions
        loc_qs = np.array([av_col['q1'], av_col['q2'], av_col['q3'], av_col['q4']])
        soc_qs = np.array([av_col['q5'], av_col['q6'], av_col['q7'], av_col['q8']])
        #averaging location and social questions
        avg_loc = np.nanmean(loc_qs)
        avg_soc = np.nanmean(soc_qs)              
        avgs[i][key] = np.array([avg_loc, avg_soc])
# Out:
# this is:  0
# this is:  1
# this is:  2

# %% [markdown]
# ## C. Bar graph plotting for each priming type and story the average location and social question scores
# ### - green = avg location question score; blue = avg social question score

# %%
figure, axes = plt.subplots(nrows=4, ncols=4, figsize=(20, 30))
# Set the ticks and ticklabels for all axes
plt.setp(axes, xticks=[0, 1, 2, 3], xticklabels=['No Prime', 'Location', 'Social'],
        yticks=[0, 1, 2, 3])
# set width of bar
barWidth = 0.25
i = 0
j = 0
for key in avg_ss.keys():
    # set height of bar
    loc = np.array([avg_ss_0[key][0], avg_ss_1[key][0], avg_ss_2[key][0]])
    soc = np.array([avg_ss_0[key][1], avg_ss_1[key][1], avg_ss_2[key][1]])
    
    if key == 33:
        print(loc)
        print(soc)
    
    #nan to num
    loc = np.nan_to_num(loc)
    soc = np.nan_to_num(soc)
    
    #get the number of participants in each group
    num_0 = str(len(ss_0[key]))
    num_1 = str(len(ss_1[key]))
    num_2 = str(len(ss_2[key]))
    title = str(key) + ": no prime = " + num_0 + "; loc = " + num_1 + "; soc = " + num_2
    
    # Set position of bar on X axis
    r1 = np.arange(len(loc))
    r2 = [x + barWidth for x in r1]

    # Make the plot
    axes[j, i].bar(r1, loc, color='#1dc149', width=barWidth, edgecolor='white')
    axes[j, i].bar(r2, soc, color= '#f542aa', width=barWidth, edgecolor='white')
    
    #set title
    
    axes[j, i].set_title(title)
    
    # Add xticks on the middle of the group bars
    #axes[i, j].set_xlabel(key, fontweight='bold')
    axes[j, i].set_yticks([0, 1, 2, 3])
    
    
    #changing i, j for next graph placement
    if i == 3:
        i = 0
        j += 1
    else:
        i += 1
    figure.tight_layout()
# Out:
# [1.6578125  1.44027778 1.7703125 ]
# [1.059375   1.11111111 1.834375  ]

# %% [markdown]
# ## D. Average location score and social score across all stories

# %%
l_scores_0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-67b499dcd9c6> in <module>
# ----> 1 l_scores_0
#
# NameError: name 'l_scores_0' is not defined

# %%
l_scores_0 = []
s_scores_0 = []
l_scores_1 = []
s_scores_1 = []
l_scores_2 = []
s_scores_2 = []

sss = [ss_0, ss_1, ss_2]
loc_s = [l_scores_0, l_scores_1, l_scores_2]
soc_s = [s_scores_0, s_scores_1, s_scores_2]

for i in range(0,3):
    print('this is: ', i)
    for key in sss[i].keys():
        # Iterating through each row in each story
        for index, row in sss[i][key].iterrows():
            # Collecting location and social questions
            loc_qs = np.array([row['q1'], row['q2'], row['q3'], row['q4']])
            soc_qs = np.array([row['q5'], row['q6'], row['q7'], row['q8']])
            # Averaging location and social questions
            avg_loc = np.nanmean(loc_qs)
            avg_soc = np.nanmean(soc_qs)  
            # Append averaged values for each participant into the correct list
            loc_s[i].append(avg_loc)
            soc_s[i].append(avg_soc)
            
# Concerting each list to a np array
npl_scores_0 = np.asarray(l_scores_0)
nps_scores_0 = np.asarray(s_scores_0)
npl_scores_1 = np.asarray(l_scores_1)
nps_scores_1 = np.asarray(s_scores_1)
npl_scores_2 = np.asarray(l_scores_2)
nps_scores_2 = np.asarray(s_scores_2)

# Finding the average of each list
al_0 = np.mean(npl_scores_0)
as_0 = np.mean(nps_scores_0)
al_1 = np.mean(npl_scores_1)
as_1 = np.mean(nps_scores_1)
al_2 = np.mean(npl_scores_2)
as_2 = np.mean(nps_scores_2)

# Standard Deviation
# Finding the average of each list
sd_l_0 = np.std(npl_scores_0)
sd_s_0 = np.std(nps_scores_0)
sd_l_1 = np.std(npl_scores_1)
sd_s_1 = np.std(nps_scores_1)
sd_l_2 = np.std(npl_scores_2)
sd_s_2 = np.std(nps_scores_2)

# Plotting

# Arranging the loc and soc means
loc_means = (al_0, al_1, al_2)
loc_sd = (sd_l_0, sd_l_1, sd_l_2) 
soc_means = (as_0, as_1, as_2)
soc_sd = (sd_s_0, sd_s_1, sd_s_2)

ind = np.arange(3)  # the x locations for the groups
width = 0.35       # the width of the bars

fig, ax = plt.subplots()

rects1 = ax.bar(ind, loc_means, width, color = '#1dc149', edgecolor='white', yerr = loc_sd)
rects2 = ax.bar(ind + width, soc_means, width, color = '#f542aa', edgecolor='white', yerr = soc_sd)

# add some text for labels, title and axes ticks
ax.set_ylabel('Score')
ax.set_ylim([0, 3])
ax.set_title('Average location and social scores across all stories')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(('No-prime', 'Loc', 'Soc'))

ax.legend((rects1[0], rects2[0]), ('Loc', 'Soc'))


plt.show()
# Out:
# this is:  0
# this is:  1
# this is:  2

# %% [markdown]
# # V. Difference between location and social scores
# ### -subtracting for each story and priming type avg loc score from avg soc score
# ### - [soc-loc]
# ## A. Finding this difference for each story

# %%
avg_ss_0[11]
# Out:
# array([1.00224359, 1.32083333])

# %%
figure, axes = plt.subplots(nrows=4, ncols=4, figsize=(20, 30))
# Set the ticks and ticklabels for all axes
plt.setp(axes, xticks=[0, 1, 2, 3], xticklabels=['No Prime', 'Location', 'Social'],
        yticks=[0, 1, 2, 3])
# set width of bar
barWidth = 0.5
i = 0
j = 0
for key in avg_ss.keys():
    
    #soc avg - loc avg for each priming type
    dif_0 = avg_ss_0[key][1] - avg_ss_0[key][0]
    dif_1 = avg_ss_1[key][1] - avg_ss_1[key][0]
    dif_2 = avg_ss_2[key][1] - avg_ss_2[key][0]
    
    #set height of bar
    dif = np.array([dif_0, dif_1, dif_2])
    
    #nan to num
    dif = np.nan_to_num(dif)
    
    #get the number of participants in each group
    num_0 = str(len(ss_0[key]))
    num_1 = str(len(ss_1[key]))
    num_2 = str(len(ss_2[key]))
    title = str(key) + ": no prime = " + num_0 + "; loc = " + num_1 + "; soc = " + num_2
    
    # Set position of bar on X axis
    r1 = np.arange(len(dif))

    # Make the plot
    axes[j, i].bar(r1, dif, color=['#f5c842', '#42f55d', '#f542e6'] , width=barWidth, edgecolor='white')
    
    #set title
    axes[j, i].set_title(title)
    
    #drawing x axis
    axes[j, i].axhline(y=0, color = '#000000')
    
    # Add xticks on the middle of the group bars
    #axes[i, j].set_xlabel(key, fontweight='bold')
    axes[j, i].set_yticks([0, 1, 2, 3])
    
    
    #changing i, j for next graph placement
    if i == 3:
        i = 0
        j += 1
    else:
        i += 1
    figure.tight_layout()

# %% [markdown]
# ## B. Averaging the differences in loc and soc scores across all stories

# %%
#iterating over all the stories

all_difs = np.zeros((16, 6))
count = 0

for key in avg_ss.keys():
    
    #finding difference between avg soc question score and avg loc question score
    dif_0 = avg_ss_0[key][1] - avg_ss_0[key][0]
    dif_1 = avg_ss_1[key][1] - avg_ss_1[key][0]
    dif_2 = avg_ss_2[key][1] - avg_ss_2[key][0]
    
    #getting the number of participants in each group
    num_0 = len(ss_0[key])
    num_1 = len(ss_1[key])
    num_2 = len(ss_2[key])
    
    #putting vals into array
    all_difs[count:] = np.array([dif_0, dif_1, dif_2, num_0, num_1, num_2])
    count += 1

#average column-wise to get average differences in loc-soc scores
avg_dif = np.nanmean(all_difs, axis = 0)

#sum column-wise to get sum of participants in each group 
sum_dif = np.sum(all_difs, axis = 0)
sum_0 = str(int(sum_dif[3]))
sum_1 = str(int(sum_dif[4]))
sum_2 = str(int(sum_dif[5]))

#plotting
# Set position of bars on X axis
r1 = np.arange(len(dif))
plt.bar(r1, avg_dif[0:3], color=['#f5c842', '#42f55d', '#f542e6'] , width=barWidth, edgecolor='white')
plt.title('Avg dif of all stories: no prime = ' +  sum_0 + '; loc = ' + sum_1 + "; soc = " + sum_2)
plt.ylim(0, .9)
# Out:
# (0, 0.9)

# %% [markdown]
# ## C. Making a df of the loc and soc primed differences for each story to export as a csv

# %%
data = [{'loc_p': all_difs[:,1]}, {'soc_p': all_difs[:,2]}]
df = pd.DataFrame({'loc_p': all_difs[:,1],'soc_p': all_difs[:,2]})
df.to_csv('csv/dif_vals.csv', index=False)

# %% [markdown]
# # VI. Priming Effect: Difference between location and social difference of location primed and social primed participants
# ### - [loc(l) - soc(l)] - [loc(s) - soc(s)]
# ## A. For each story

# %%
story_list = ['11', '12', '13', '14', '21', '22', '23', '24', '31', '32', '33', '34', '41', '42', '43', '44']

# Initiating array for storing value for each story
priming_vals = np.zeros((16))
count = 0

for key in avg_ss.keys():
    
    #finding difference between avg loc question score and avg soc question score
    dif_1 = avg_ss_1[key][0] - avg_ss_1[key][1]
    dif_2 = avg_ss_2[key][0] - avg_ss_2[key][1]
    
    #difference of the difference
    val = dif_1 - dif_2
    
    #putting vals into array
    priming_vals[count] = val
    count += 1


#plotting
# Set position of bars on X axis
r1 = np.arange(16)

plt.figure(figsize=(20,10))

plot_vals = np.nan_to_num(priming_vals)
plt.bar(story_list, plot_vals, color= '#b264d9' , width=barWidth, edgecolor='white')
plt.title('Priming Effect')
#drawing x axis
plt.axhline(y=0, color = '#000000')

# %% [markdown]
# ## B. Average Priming Effect

# %%
mean_pe = np.nanmean(priming_vals)
print(mean_pe)
# Out:
# 0.50885246625481
