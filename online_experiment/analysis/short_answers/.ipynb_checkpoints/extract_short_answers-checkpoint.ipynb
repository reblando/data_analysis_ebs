# %%
import pandas as pd
import numpy as np
import plotly.graph_objs as go
import plotly.plotly as py
import plotly
import os
import glob
import math
import statistics
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import copy
import csv
from datetime import date

# %autosave 5
# Out:
# Autosaving every 5 seconds

# %% [markdown]
# # Organizing Shorts Answers by Story
#
# ### i. importing data_dict

# %%
filename = '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/parsing_log_file/pickle/data_dict_pilots_b1.p'
data_dict = pickle.load( open( filename, "rb" ) )

# %% [markdown]
# ### ii. title of the output

# %%
folder_name = 'us_pilots_b1/'

# %% [markdown]
# ### ii. figuring out which files need sa_order edited

# %%
for key in data_dict:
    if isinstance(data_dict[key]['sa_order'].iloc[0], int) or isinstance(data_dict[key]['sa_order'].iloc[0], np.int64):
        pass
    else:
        print(key)
        print('p_type', data_dict[key]['p_type'].iloc[0])
        print('persp', data_dict[key]['persp'].iloc[0])
        print(data_dict[key]['sa_order'].iloc[0])

#type(data_dict['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot1/7/PARTICIPANT_1_online_exp_2020-05-20_17h03.06.828']['sa_order'].iloc[0])
# Out:
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot1/7/PARTICIPANT_1_online_exp_2020-05-06_20h00.18.643
# p_type 0
# persp 1
# "How is the restaurant decorated?"
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot1/7/PARTICIPANT_1_online_exp_2020-05-07_00h46.51.319
# p_type 0
# persp 3
# "What is the grocery store like upon entering?\n"
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot1/7/PARTICIPANT_1_online_exp_2020-05-07_23h36.54.796
# p_type 0
# persp 4
# "What object is the initiator of the interaction holding when he/she first notices the other person?"
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot1/7/PARTICIPANT_1_online_exp_2020-05-07_23h40.02.268
# p_type 1
# persp 3
# "For how long has the couple been dating?"
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot1/7/PARTICIPANT_1_online_exp_2020-05-09_01h01.48.508
# p_type 2
# persp 10
# "When the clients arrive at the airport, how much time do they have until their flight departs?\n"
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot1/7/PARTICIPANT_1_online_exp_2020-05-09_01h05.05.369
# p_type 1
# persp 1
# "How is the restaurant decorated?"
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot1/7/PARTICIPANT_1_online_exp_2020-05-09_01h54.27.962
# p_type 0
# persp 4
# "What object is the initiator of the interaction holding when he/she first notices the other person?"
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_12h52.50.131
# p_type 2
# persp 40
# "What is the grocery store like upon entering?\n"
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_20h42.51.597
# p_type 0
# persp 2
# "For how long has the initiator of the breakup been thinking about breaking up with his/her partner?"
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_20h43.08.493
# p_type 1
# persp 3
# "For how long has the couple been dating?"
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-12_19h57.55.241
# p_type 2
# persp 20
# "For how long has the couple been dating?"
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_15h04.13.258
# p_type 2
# persp 10
# "For how long has the initiator of the breakup been thinking about breaking up with his/her partner?"
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h16.09.618
# p_type 0
# persp 3
# "For how long has the couple been dating?"
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h17.04.991
# p_type 0
# persp 3
# "What is the grocery store like upon entering?\n"
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h18.58.644
# p_type 2
# persp 30
# "What is the grocery store like upon entering?\n"

# %% [markdown]
# ### iii. Hard-coding sa_order for participants of the first two pilots which did not include these variable
# # (only run when pilot 1 and 2 data are included)

# %%
data_dict['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot1/7/PARTICIPANT_1_online_exp_2020-05-06_20h00.18.643']['sa_order'] = 0

data_dict['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot1/7/PARTICIPANT_1_online_exp_2020-05-07_00h46.51.319']['sa_order'] = 0

data_dict['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot1/7/PARTICIPANT_1_online_exp_2020-05-07_23h36.54.796']['sa_order'] = 1

data_dict['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot1/7/PARTICIPANT_1_online_exp_2020-05-07_23h40.02.268']['sa_order'] = 1

data_dict['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot1/7/PARTICIPANT_1_online_exp_2020-05-09_01h01.48.508']['sa_order'] = 1

data_dict['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot1/7/PARTICIPANT_1_online_exp_2020-05-09_01h05.05.369']['sa_order'] = 0

data_dict['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot1/7/PARTICIPANT_1_online_exp_2020-05-09_01h54.27.962']['sa_order'] = 1

data_dict['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_12h52.50.131']['sa_order'] = 1

data_dict['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_20h42.51.597']['sa_order'] = 1

data_dict['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_20h43.08.493']['sa_order'] = 1

data_dict['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-12_19h57.55.241']['sa_order'] = 0

data_dict['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_15h04.13.258']['sa_order'] = 0

data_dict['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h16.09.618']['sa_order'] = 1

data_dict['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h17.04.991']['sa_order'] = 0

data_dict['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h18.58.644']['sa_order'] = 1

# %%
data_dict['/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_20h42.51.597']
# Out:
#     story_presses          A1                A2  \
# 0               1  " 6 weeks"  "not getting on"
# 1               1  " 6 weeks"  "not getting on"
# 2               9  " 6 weeks"  "not getting on"
# 3               9  " 6 weeks"  "not getting on"
# 4               9  " 6 weeks"  "not getting on"
# 5               1  " 6 weeks"  "not getting on"
# 6               1  " 6 weeks"  "not getting on"
# 7               9  " 6 weeks"  "not getting on"
# 8               9  " 6 weeks"  "not getting on"
# 9               1  " 6 weeks"  "not getting on"
# 10              1  " 6 weeks"  "not getting on"
# 11              9  " 6 weeks"  "not getting on"
# 12              9  " 6 weeks"  "not getting on"
# 13              1  " 6 weeks"  "not getting on"
# 14              1  " 6 weeks"  "not getting on"
# 15              1  " 6 weeks"  "not getting on"
# 16              1  " 6 weeks"  "not getting on"
# 17              1  " 6 weeks"  "not getting on"
# 18              9  " 6 weeks"  "not getting on"
# 19              9  " 6 weeks"  "not getting on"
# 20              9  " 6 weeks"  "not getting on"
# 21              9  " 6 weeks"  "not getting on"
# 22              9  " 6 weeks"  "not getting on"
# 23              1  " 6 weeks"  "not getting on"
# 24              9  " 6 weeks"  "not getting on"
# 25              9  " 6 weeks"  "not getting on"
# 26              9  " 6 weeks"  "not getting on"
# 27              9  " 6 weeks"  "not getting on"
# 28              1  " 6 weeks"  "not getting on"
# 29              9  " 6 weeks"  "not getting on"
# 30              9  " 6 weeks"  "not getting on"
#
#                                       A3        A4        A5  \
# 0   "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 1   "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 2   "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 3   "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 4   "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 5   "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 6   "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 7   "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 8   "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 9   "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 10  "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 11  "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 12  "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 13  "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 14  "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 15  "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 16  "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 17  "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 18  "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 19  "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 20  "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 21  "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 22  "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 23  "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 24  "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 25  "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 26  "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 27  "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 28  "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 29  "no, didnt think anything was wrong"  "calvin"  "1 hour"
# 30  "no, didnt think anything was wrong"  "calvin"  "1 hour"
#
#                      A6   A7         A8     distractor1  ...    distractor3  \
# 0   "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 1   "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 2   "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 3   "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 4   "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 5   "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 6   "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 7   "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 8   "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 9   "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 10  "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 11  "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 12  "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 13  "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 14  "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 15  "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 16  "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 17  "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 18  "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 19  "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 20  "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 21  "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 22  "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 23  "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 24  "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 25  "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 26  "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 27  "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 28  "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 29  "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
# 30  "the conveyor belt"  "3"  "economy"  "accroutments"  ...  "hippocampus"
#
#      distractor4   distractor5               prolific_id story  p_type  persp  \
# 0   "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 1   "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 2   "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 3   "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 4   "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 5   "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 6   "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 7   "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 8   "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 9   "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 10  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 11  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 12  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 13  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 14  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 15  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 16  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 17  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 18  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 19  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 20  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 21  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 22  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 23  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 24  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 25  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 26  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 27  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 28  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 29  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
# 30  "brigaderio"  "muffuletta"  5ce5b9844cd8130019acba32    12       0      2
#
#     alt_persp  sa_order                                             recall
# 0          10         1  arrived at the airport, went through the secur...
# 1          10         1  arrived at the airport, went through the secur...
# 2          10         1  arrived at the airport, went through the secur...
# 3          10         1  arrived at the airport, went through the secur...
# 4          10         1  arrived at the airport, went through the secur...
# 5          10         1  arrived at the airport, went through the secur...
# 6          10         1  arrived at the airport, went through the secur...
# 7          10         1  arrived at the airport, went through the secur...
# 8          10         1  arrived at the airport, went through the secur...
# 9          10         1  arrived at the airport, went through the secur...
# 10         10         1  arrived at the airport, went through the secur...
# 11         10         1  arrived at the airport, went through the secur...
# 12         10         1  arrived at the airport, went through the secur...
# 13         10         1  arrived at the airport, went through the secur...
# 14         10         1  arrived at the airport, went through the secur...
# 15         10         1  arrived at the airport, went through the secur...
# 16         10         1  arrived at the airport, went through the secur...
# 17         10         1  arrived at the airport, went through the secur...
# 18         10         1  arrived at the airport, went through the secur...
# 19         10         1  arrived at the airport, went through the secur...
# 20         10         1  arrived at the airport, went through the secur...
# 21         10         1  arrived at the airport, went through the secur...
# 22         10         1  arrived at the airport, went through the secur...
# 23         10         1  arrived at the airport, went through the secur...
# 24         10         1  arrived at the airport, went through the secur...
# 25         10         1  arrived at the airport, went through the secur...
# 26         10         1  arrived at the airport, went through the secur...
# 27         10         1  arrived at the airport, went through the secur...
# 28         10         1  arrived at the airport, went through the secur...
# 29         10         1  arrived at the airport, went through the secur...
# 30         10         1  arrived at the airport, went through the secur...
#
# [31 rows x 21 columns]

# %% [markdown]
# ## A. Organize short answers by story

# %%
#create a dictionary for the answers to the 8 questions for each story, not parsing the questions 
#by primed or unprimed

#date
today = str(date.today())

question_answers = dict()

for key in data_dict:
    #get the short answer order
    sa_order = data_dict[key]['sa_order'].iloc[0]
    story = data_dict[key]['story'].iloc[0]
    persp = data_dict[key]['persp'].iloc[0]
    p_id = data_dict[key]['prolific_id'].iloc[0]
    p_type = data_dict[key]['p_type'].iloc[0]
    
    a1 = data_dict[key]['A1'].iloc[0]
    a2 = data_dict[key]['A2'].iloc[0]
    a3 = data_dict[key]['A3'].iloc[0]
    a4 = data_dict[key]['A4'].iloc[0]
    a5 = data_dict[key]['A5'].iloc[0]
    a6 = data_dict[key]['A6'].iloc[0]
    a7 = data_dict[key]['A7'].iloc[0]
    a8 = data_dict[key]['A8'].iloc[0]
    
    #location primed
    if persp < 9:
        if sa_order == 0:
            new_questions = [today, p_id, story, persp, p_type, a1, a2, a3, a4, a5, a6, a7, a8]
        else:
            new_questions = [today, p_id, story, persp, p_type, a5, a6, a7, a8, a1, a2, a3, a4]
    else:
        if sa_order == 1:
            new_questions = [today, p_id, story, persp, p_type, a1, a2, a3, a4, a5, a6, a7, a8]
        else:
            new_questions = [today, p_id, story, persp, p_type, a5, a6, a7, a8, a1, a2, a3, a4]

    #put all of the questions into dictionaries organized by story
    if story in question_answers:    
        question_answers[story] = np.vstack((question_answers[story], new_questions))
    else:
        question_answers[story] = new_questions

# %% [markdown]
# ## B. Export each story answers to its own CSV file

# %%
for key in question_answers:
    title = folder_name + str(key) + '_shortanswers.csv'
    this_array = question_answers[key]
    with open(title, 'w') as csvfile:
        fieldnames = ['date', 'prolific_id', 'story', 'persp', 'p_type', '1','q1', '2','q2', '3','q3', '4','q4','5','q5', '6','q6','7','q7','8','q8']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        #for stories w one participant:
        if isinstance(this_array, list):
            a = this_array[0]
            b = this_array[1]
            c = this_array[2]
            d = this_array[3]
            e = this_array[4]
            f = this_array[5]
            g = this_array[6]
            h = this_array[7]
            j = this_array[8]
            k = this_array[9]
            l = this_array[10]
            m = this_array[11]
            n = this_array[12]
            writer.writerow({'date': a, 'prolific_id': b, 'story': c, 'persp': d, 'p_type': e, '1': f, 'q1':'', '2': g,'q2':'',
                         '3': h, 'q3':'', '4':j, 'q4':'', '5':k, 'q5':'', '6':l, 'q6':'', '7':m, 'q7':'', '8':n, 'q8':''})
        else:
            for i in range(len(this_array)):
                a = this_array[i][0]
                b = this_array[i][1]
                c = this_array[i][2]
                d = this_array[i][3]
                e = this_array[i][4]
                f = this_array[i][5]
                g = this_array[i][6]
                h = this_array[i][7]
                j = this_array[i][8]
                k = this_array[i][9]
                l = this_array[i][10]
                m = this_array[i][11]
                n = this_array[i][12]
                writer.writerow({'date': a, 'prolific_id': b, 'story': c, 'persp': d, 'p_type': e, '1': f, 'q1':'', '2': g,'q2':'',
                         '3': h, 'q3':'', '4':j, 'q4':'', '5':k, 'q5':'', '6':l, 'q6':'', '7':m, 'q7':'', '8':n, 'q8':''})
