# %%
import re
import codecs
import glob
import csv
import pandas as pd
import numpy as np
import pickle
# %autosave 5
# Out:
# Autosaving every 5 seconds

# %% [markdown]
# # Constructing Standard Data Files for Online Participants
# ##### 5/27/20
# ## I. Treating Log Files
# ### A. Reading in Log Files

# %%
#pilot1
files1 = glob.glob("/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot1/7/*.log")

#pilot2
files2 = glob.glob("/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/*.log")

#pilot3
files3 = glob.glob("/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot3/4/*.log")

#pilot4
files4 = glob.glob("/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot4/7/*.log")

#final ver- p
filesp = glob.glob("/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/finalver_p/10/*.log")

#final ver- b1
filesb1 = glob.glob("/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/finalver_b1/33/*.log")



files = files1 + files2 + files3 + files4 + filesp + filesb1
# we'll use a regex for this even though they're ugly and painful:
scanQuote = re.compile(r"'(.*?)'")  # finds any number of words within a quote
print(len(files))
# Out:
# 69

# %% [markdown]
# ### B. Creating dictionary files_pd with log files data filtered (key: filename .log)

# %%
#instantiate dictionary
files_pd = {}

for filename in files:
    print(filename)
    # open log file
    thisFile = codecs.open( filename, 'r', 'utf-8')
    #initiate a dataframe
    df = pd.DataFrame(columns=['time','keypress'])
    #go through each line in the file
    for line in thisFile.readlines():
        if "DATA" in line:  # new trial reset all entries
            if "Keydown:" in line:
                first, keypress = line.split("Keydown:")
                time = first.split("\t")[0]
                keypress = keypress.strip()
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
            else:
                pass
        if "text_34: autoDraw = false" in line:
            time = "here"
            keypress = 33
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        #recording the distractor words    
        if "text_66: text =" in line:
            time = 'distractor_text'
            b, keypress = line.split("text = ")
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        #mark the end of the distractor typing
        if "instr_9: autoDraw = false" in line:
            time = 44
            keypress = 0
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        #recording the short answer questions
        if "instr: text =" in line:
            b, keypress = line.split("text = ")
            time = 'Q1'
            keypress = keypress.strip()
            if keypress == "\"default text\"":
                pass
            else:
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "instr_2: text =" in line:
            b, keypress = line.split("text = ")
            time = 'Q2'
            keypress = keypress.strip()
            if keypress == "\"default text\"":
                pass
            else:
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "instr_3: text =" in line:
            b, keypress = line.split("text = ")
            time = 'Q3'
            keypress = keypress.strip()
            if keypress == "\"default text\"":
                pass
            else:
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "instr_4: text =" in line:
            b, keypress = line.split("text = ")
            time = 'Q4'
            keypress = keypress.strip()
            if keypress == "\"default text\"":
                pass
            else:
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "instr_5: text =" in line:
            b, keypress = line.split("text = ")
            time = 'Q5'
            keypress = keypress.strip()
            if keypress == "\"default text\"":
                pass
            else:
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "instr_6: text =" in line:
            b, keypress = line.split("text = ")
            time = 'Q6'
            keypress = keypress.strip()
            if keypress == "\"default text\"":
                pass
            else:
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "instr_7: text =" in line:
            b, keypress = line.split("text = ")
            time = 'Q7'
            keypress = keypress.strip()
            if keypress == "\"default text\"":
                pass
            else:
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "instr_8: text =" in line:
            b, keypress = line.split("text = ")
            time = 'Q8'
            keypress = keypress.strip()
            if keypress == "\"default text\"":
                pass
            else:
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        #short answers
        text_num = ["43", "44", "45", "46", "47", "48", "51", "53"]
        if "text_43: text = " in line:
            b, keypress = line.split("text = ")
            time = 'A1'
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "text_44: text = " in line:
            b, keypress = line.split("text = ")
            time = 'A2'
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "text_45: text = " in line:
            b, keypress = line.split("text = ")
            time = 'A3'
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "text_46: text = " in line:
            b, keypress = line.split("text = ")
            time = 'A4'
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "text_47: text = " in line:
            b, keypress = line.split("text = ")
            time = 'A5'
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "text_48: text = " in line:
            b, keypress = line.split("text = ")
            time = 'A6'
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "text_51: text = " in line:
            b, keypress = line.split("text = ")
            time = 'A7'
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "text_53: text = " in line:
            b, keypress = line.split("text = ")
            time = 'A8'
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
    #remove rows of pd with empty keypress values
    df = df[df.keypress != '""']
    df = df[df.keypress != '']
    #reset index
    df = df.reset_index(drop=True)
    #add the df to the dictionary
    files_pd[filename] = df
# Out:
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot1/7/PARTICIPANT_1_online_exp_2020-05-06_20h00.18.643.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot1/7/PARTICIPANT_1_online_exp_2020-05-07_00h46.51.319.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot1/7/PARTICIPANT_1_online_exp_2020-05-07_23h36.54.796.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot1/7/PARTICIPANT_1_online_exp_2020-05-07_23h40.02.268.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot1/7/PARTICIPANT_1_online_exp_2020-05-09_01h01.48.508.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot1/7/PARTICIPANT_1_online_exp_2020-05-09_01h05.05.369.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot1/7/PARTICIPANT_1_online_exp_2020-05-09_01h54.27.962.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_12h52.50.131.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_20h42.51.597.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-11_20h43.08.493.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-12_19h57.55.241.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_15h04.13.258.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h16.09.618.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h17.04.991.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot2/8/PARTICIPANT_1_online_exp_2020-05-19_19h18.58.644.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot3/4/PARTICIPANT_1_online_exp_2020-05-20_16h02.59.817.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot3/4/PARTICIPANT_1_online_exp_2020-05-20_17h03.06.828.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot3/4/PARTICIPANT_1_online_exp_2020-05-20_22h01.43.581.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot3/4/PARTICIPANT_1_online_exp_2020-05-20_22h03.41.810.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot4/7/PARTICIPANT_1_online_exp_2020-05-22_13h49.27.322.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot4/7/PARTICIPANT_1_online_exp_2020-05-22_16h32.49.800.log
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/pilot4/7/PARTICIPANT_1_online_exp_2020-05
csv
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/finalver_b1/33/61_1_online_exp_2020-06-10_21h06.18.577.csv
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/finalver_b1/33/64_1_online_exp_2020-06-10_15h07.52.732.csv
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/finalver_b1/33/65_1_online_exp_2020-06-10_21h06.10.380.csv
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/finalver_b1/33/67_1_online_exp_2020-06-10_22h11.26.915.csv
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/finalver_b1/33/69_1_online_exp_2020-06-10_15h07.03.668.csv
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/finalver_b1/33/70_1_online_exp_2020-06-10_21h07.29.172.csv
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/finalver_b1/33/71_1_online_exp_2020-06-10_16h08.46.721.csv
# /Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/finalver_b1/33/73_1_online_exp_2020-06-10_14h37.05.252.csv
# done!

# %%
len(csvnames)
# Out:
# 69

# %% [markdown]
# ## C. Extract information from files_pd
# ### i. story_presses

# %%
#include if statement, since if the values are in the .csv we will use those, maybe not actually. If this method works
#why not make it ubiquitous for all. I will do some comparisons with people who do have story_presses in their .csv
#to verify this extraction method

for filename in files:
    #call the dataframe for this file
    df = files_pd[filename]
    #finding index of 'here'
    here = np.array(df.index[df['time'] == 'here'].tolist())
    #subtracting 1 to get index of keypresses
    seg = here - 1
    #getting the keypress values
    key_vals = df['keypress'][seg].tolist()
    #turning keypresses into ints
    key_vals = [int(i) for i in key_vals]
    #adjusting the filename to match the key
    label = filename[:-4]
    #adding the key_vals to the df
    data_dict[label]['story_presses'] = key_vals

# %% [markdown]
# ### ii. short answers

# %%
Alist = ['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8']

for filename in files:
    df = files_pd[filename]
    for thisA in Alist:
        #finding index of thisA
        here = np.array(df.index[df['time'] == thisA].tolist())
        #getting the keypress values
        key_vals = df['keypress'][here].tolist()
        if not key_vals:
            this_val = ''
        else:
            #index the last value
            this_val = key_vals[-1]
        label = filename[:-4]
        #adding the key_vals to the df
        data_dict[label][thisA] = this_val

# %%
labeoz
# Out:
# '/Users/alexreblando/Documents/GitHub/data_analysis_ebs/online_experiment/finalver_b1/33/73_1_online_exp_2020-06-10_14h37.05.252'

# %% [markdown]
# ### iii. distractors

# %%
for filename in files:
    print(filename)
    #get the label for the data_dict
    label = filename[:-4]
    #select df from files_pd
    df = files_pd[filename]
    #finding the index of 44, the marker for distractor texts
    here = np.array(df.index[df['time'] == 44].tolist())
    #subtracting 2 to get index of keypresses
    distractors = here - 2
    distractor_vals = df['keypress'][distractors].tolist()
    for i in range(0, 5):
        data_dict[label]['distractor' + str(i+1)] = distractor_vals[i]
# Out:
# 138_1_online_exp_2020-06-10_21h22.49.032.log
# 139_1_online_exp_2020-06-10_21h13.18.162.log
# 143_1_online_exp_2020-06-10_21h17.07.791.log
# 145_1_online_exp_2020-06-10_15h14.14.911.log
# 147_1_online_exp_2020-06-10_16h14.06.750.log
# 148_1_online_exp_2020-06-10_21h14.16.649.log
# 150_1_online_exp_2020-06-10_21h16.30.855.log
# 152_1_online_exp_2020-06-10_21h15.29.074.log
# 153_1_online_exp_2020-06-10_21h15.16.908.log
# 157_1_online_exp_2020-06-11_09h44.06.040.log
# 171_1_online_exp_2020-06-10_21h32.27.534.log
# 174_1_online_exp_2020-06-10_21h49.17.497.log
# 177_1_online_exp_2020-06-10_14h45.30.620.log
# 179_1_online_exp_2020-06-10_21h46.36.458.log
# 1     3.820530000000872         v
# 2     98.91785499999969     Enter
# 3    210.61395500000071         a
# 4     216.4614849999998         1
# ..                  ...       ...
# 422   958.8571850000008         e
# 423                  A8   "siste"
# 424   958.9885700000013         r
# 425                  A8  "sister"
# 426   959.9925199999998     Enter
#
# [427 rows x 2 columns]

# %% [markdown]
# ## D. Extract info from CSV files
# ### i. Get prolific_id, story, type, persp, alt_persp, sa_order

# %%
for filename in files:
    #get the label for the data_dict
    label = filename[:-4]
    #getting prolific id
    data_dict[label]['prolific_id'] = csv_df[label]['Prolific_ID'].iloc[0]
    #getting story number
    data_dict[label]['story'] = int(csv_df[label]['story'].iloc[0])
    #getting priming type
    data_dict[label]['p_type'] = int(csv_df[label]['val2'].iloc[0])
    #perspective
    if "persp_val" in csv_df[label]:
        data_dict[label]['persp'] = int(csv_df[label]['persp_val'].iloc[0])
        #alternative perspective
        data_dict[label]['alt_persp'] = int(csv_df[label]['alt_persp_val'].iloc[0])
    else:
        data_dict[label]['persp'] = int(csv_df[label]['perp_val'].iloc[0])
        #alternative perspective
        data_dict[label]['alt_persp'] = int(csv_df[label]['alt_perp_val'].iloc[0])
    #short answer order
    if "sa_order" in csv_df[label]:
        data_dict[label]['sa_order'] = int(csv_df[label]['sa_order'].iloc[0])
    #if the short answer order is not in the file (pilot i, ii) then put the first sa question in 'sa_order' column    
    else:
        data_dict[label]['sa_order'] = files_pd[filename].loc[files_pd[filename]['time'] == 'Q1', 'keypress'].iloc[0]

# %% [markdown]
# ## E. Recall Data from Qualtrics
# ### i. load CSV from Qualtrics

# %%
q_df = pd.read_csv("qualtrics/qualtrics.csv")

# %% [markdown]
# ### ii. Insert Recall Data from Qualtrics CSV into data_dict using prolific_id

# %%
for key in data_dict.keys():
    print(key)
    #getting prolific id from data_dict
    this_id = data_dict[key]['prolific_id'].iloc[0]
    print(this_id)
    this_id_new = this_id.strip()
    print(this_id)
    if this_id in q_df.values:
        #index of row with this_id
        data_dict[key]['recall'] = q_df.loc[q_df['Q1'] == this_id, 'Q8'].iloc[0]
    elif this_id_new in q_df.values:
        data_dict[key]['recall'] = q_df.loc[q_df['Q1'] == this_id_new, 'Q8'].iloc[0]
# Out:
# 138_1_online_exp_2020-06-10_21h22.49.032
# 5b88
# 5b88
# 139_1_online_exp_2020-06-10_21h13.18.162
# 5ec7a3794f89b8205c25fba3
# 5ec7a3794f89b8205c25fba3
# 143_1_online_exp_2020-06-10_21h17.07.791
# 5d2e1f674819d00019efd516
# 5d2e1f674819d00019efd516
# 145_1_online_exp_2020-06-10_15h14.14.911
# 5ec18c4c2f44695b38204649
# 5ec18c4c2f44695b38204649
# 147_1_online_exp_2020-06-10_16h14.06.750
# 5ed9232765948647682f2a62
# 5ed9232765948647682f2a62
# 148_1_online_exp_2020-06-10_21h14.16.649
# 5c17c149f596b100011ca8b8
# 5c17c149f596b100011ca8b8
# 150_1_online_exp_2020-06-10_21h16.30.855
ARTICIPANT_1_online_exp_2020-05-11_20h42.51.597
# 5ce5b9844cd8130019acba32
# 5ce5b9844cd8130019acba32
# PARTICIPANT_1_online_exp_2020-05-11_20h43.08.493
# 597cb71cd4e83700016c35b2
# 597cb71cd4e83700016c35b2
# PARTICIPANT_1_online_exp_2020-05-12_19h57.55.241
# 5e7b804f9379140478c688da
# 5e7b804f9379140478c688da
# PARTICIPANT_1_online_exp_2020-05-19_15h04.13.258
# 5eac5376dfc1010c08a633bb
# 5eac5376dfc1010c08a633bb
# PARTICIPANT_1_online_exp_2020-05-19_19h16.09.618
# 5cea26087afd86001a34a5db
# 5cea26087afd86001a34a5db
# PARTICIPANT_1_online_exp_2020-05-19_19h17.04.991
# 5deae08fe4f84020dfafac72
# 5deae08fe4f84020dfafac72
# PARTICIPANT_1_online_exp_2020-05-19_19h18.58.644
# 5bc9e924e642db0001d3a1c5
# 5bc9e924e642db0001d3a1c5
# PARTICIPANT_1_online_exp_2020-05-20_16h02.59.817
# 5cc482bd8d2a1e001885c450
# 5cc482bd8d2a1e001885c450
# PARTICIPANT_1_online_exp_2020-05-20_17h03.06.828
# 5d82994758861000188f76dc
# 5d82994758861000188f76dc
# PARTICIPANT_1_online_exp_2020-05-20_22h01.43.581
# 58af6fa166d1330001eebaab
# 58af6fa166d1330001eebaab
# PARTICIPANT_1_online_exp_2020-05-20_22h03.41.810
# 5e3f032709a1141608164346
# 5e3f032709a1141608164346

# %% [markdown]
# ## F. Pickling

# %%
pickle.dump( data_dict, open( "pickle/data_dict.p", "wb" ) )

# %%
data_dict['64_1_online_exp_2020-06-10_15h07.52.732']
# Out:
#     story_presses               A1                         A2  \
# 0               1  "  a long time"  "need to find careerpath"
# 1               1  "  a long time"  "need to find careerpath"
# 2               9  "  a long time"  "need to find careerpath"
# 3               1  "  a long time"  "need to find careerpath"
# 4               9  "  a long time"  "need to find careerpath"
# 5               1  "  a long time"  "need to find careerpath"
# 6               9  "  a long time"  "need to find careerpath"
# 7               1  "  a long time"  "need to find careerpath"
# 8               1  "  a long time"  "need to find careerpath"
# 9               9  "  a long time"  "need to find careerpath"
# 10              1  "  a long time"  "need to find careerpath"
# 11              1  "  a long time"  "need to find careerpath"
# 12              1  "  a long time"  "need to find careerpath"
# 13              9  "  a long time"  "need to find careerpath"
# 14              1  "  a long time"  "need to find careerpath"
# 15              9  "  a long time"  "need to find careerpath"
# 16              1  "  a long time"  "need to find careerpath"
# 17              1  "  a long time"  "need to find careerpath"
# 18              9  "  a long time"  "need to find careerpath"
# 19              1  "  a long time"  "need to find careerpath"
# 20              1  "  a long time"  "need to find careerpath"
# 21              1  "  a long time"  "need to find careerpath"
# 22              9  "  a long time"  "need to find careerpath"
# 23              1  "  a long time"  "need to find careerpath"
# 24              9  "  a long time"  "need to find careerpath"
# 25              9  "  a long time"  "need to find careerpath"
# 26              1  "  a long time"  "need to find careerpath"
# 27              1  "  a long time"  "need to find careerpath"
# 28              1  "  a long time"  "need to find careerpath"
# 29              1  "  a long time"  "need to find careerpath"
# 30              9  "  a long time"  "need to find careerpath"
# 31              1  "  a long time"  "need to find careerpath"
# 32              9  "  a long time"  "need to find careerpath"
# 33              1  "  a long time"  "need to find careerpath"
# 34              9  "  a long time"  "need to find careerpath"
# 35              9  "  a long time"  "need to find careerpath"
# 36              9  "  a long time"  "need to find careerpath"
# 37              1  "  a long time"  "need to find careerpath"
# 38              1  "  a long time"  "need to find careerpath"
# 39              9  "  a long time"  "need to find careerpath"
# 40              9  "  a long time"  "need to find careerpath"
#
#                                            A3                             A4  \
# 0   "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 1   "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 2   "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 3   "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 4   "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 5   "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 6   "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 7   "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 8   "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 9   "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 10  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 11  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 12  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 13  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 14  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 15  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 16  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 17  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 18  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 19  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 20  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 21  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 22  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 23  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 24  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 25  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 26  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 27  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 28  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 29  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 30  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 31  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 32  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 33  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 34  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 35  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 36  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 37  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 38  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 39  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
# 40  "no she doesnt. she wants to talk it out"  "the girl wants her polaroid"
#
#                                                    A5                  A6  \
# 0   "decorated like a bar with piano type floors a...  "crazy item names"
# 1   "decorated like a bar with piano type floors a...  "crazy item names"
# 2   "decorated like a bar with piano type floors a...  "crazy item names"
# 3   "decorated like a bar with piano type floors a...  "crazy item names"
# 4   "decorated like a bar with piano type floors a...  "crazy item names"
# 5   "decorated like a bar with piano type floors a...  "crazy item names"
# 6   "decorated like a bar with piano type floors a...  "crazy item names"
# 7   "decorated like a bar with piano type floors a...  "crazy item names"
# 8   "decorated like a bar with piano type floors a...  "crazy item names"
# 9   "decorated like a bar with piano type floors a...  "crazy item names"
# 10  "decorated like a bar with piano type floors a...  "crazy item names"
# 11  "decorated like a bar with piano type floors a...  "crazy item names"
# 12  "decorated like a bar with piano type floors a...  "crazy item names"
# 13  "decorated like a bar with piano type floors a...  "crazy item names"
# 14  "decorated like a bar with piano type floors a...  "crazy item names"
# 15  "decorated like a bar with piano type floors a...  "crazy item names"
# 16  "decorated like a bar with piano type floors a...  "crazy item names"
# 17  "decorated like a bar with piano type floors a...  "crazy item names"
# 18  "decorated like a bar with piano type floors a...  "crazy item names"
# 19  "decorated like a bar with piano type floors a...  "crazy item names"
# 20  "decorated like a bar with piano type floors a...  "crazy item names"
# 21  "decorated like a bar with piano type floors a...  "crazy item names"
# 22  "decorated like a bar with piano type floors a...  "crazy item names"
# 23  "decorated like a bar with piano type floors a...  "crazy item names"
# 24  "decorated like a bar with piano type floors a...  "crazy item names"
# 25  "decorated like a bar with piano type floors a...  "crazy item names"
# 26  "decorated like a bar with piano type floors a...  "crazy item names"
# 27  "decorated like a bar with piano type floors a...  "crazy item names"
# 28  "decorated like a bar with piano type floors a...  "crazy item names"
# 29  "decorated like a bar with piano type floors a...  "crazy item names"
# 30  "decorated like a bar with piano type floors a...  "crazy item names"
# 31  "decorated like a bar with piano type floors a...  "crazy item names"
# 32  "decorated like a bar with piano type floors a...  "crazy item names"
# 33  "decorated like a bar with piano type floors a...  "crazy item names"
# 34  "decorated like a bar with piano type floors a...  "crazy item names"
# 35  "decorated like a bar with piano type floors a...  "crazy item names"
# 36  "decorated like a bar with piano type floors a...  "crazy item names"
# 37  "decorated like a bar with piano type floors a...  "crazy item names"
# 38  "decorated like a bar with piano type floors a...  "crazy item names"
# 39  "decorated like a bar with piano type floors a...  "crazy item names"
# 40  "decorated like a bar with piano type floors a...  "crazy item names"
#
#                                                    A7  \
# 0   "thomas oreder hamburger with no tomato. i for...
# 1   "thomas oreder hamburger with no tomato. i for...
# 2   "thomas oreder hamburger with no tomato. i for...
# 3   "thomas oreder hamburger with no tomato. i for...
# 4   "thomas oreder hamburger with no tomato. i for...
# 5   "thomas oreder hamburger with no tomato. i for...
# 6   "thomas oreder hamburger with no tomato. i for...
# 7   "thomas oreder hamburger with no tomato. i for...
# 8   "thomas oreder hamburger with no tomato. i for...
# 9   "thomas oreder hamburger with no tomato. i for...
# 10  "thomas oreder hamburger with no tomato. i for...
# 11  "thomas oreder hamburger with no tomato. i for...
# 12  "thomas oreder hamburger with no tomato. i for...
# 13  "thomas oreder hamburger with no tomato. i for...
# 14  "thomas oreder hamburger with no tomato. i for...
# 15  "thomas oreder hamburger with no tomato. i for...
# 16  "thomas oreder hamburger with no tomato. i for...
# 17  "thomas oreder hamburger with no tomato. i for...
# 18  "thomas oreder hamburger with no tomato. i for...
# 19  "thomas oreder hamburger with no tomato. i for...
# 20  "thomas oreder hamburger with no tomato. i for...
# 21  "thomas oreder hamburger with no tomato. i for...
# 22  "thomas oreder hamburger with no tomato. i for...
# 23  "thomas oreder hamburger with no tomato. i for...
# 24  "thomas oreder hamburger with no tomato. i for...
# 25  "thomas oreder hamburger with no tomato. i for...
# 26  "thomas oreder hamburger with no tomato. i for...
# 27  "thomas oreder hamburger with no tomato. i for...
# 28  "thomas oreder hamburger with no tomato. i for...
# 29  "thomas oreder hamburger with no tomato. i for...
# 30  "thomas oreder hamburger with no tomato. i for...
# 31  "thomas oreder hamburger with no tomato. i for...
# 32  "thomas oreder hamburger with no tomato. i for...
# 33  "thomas oreder hamburger with no tomato. i for...
# 34  "thomas oreder hamburger with no tomato. i for...
# 35  "thomas oreder hamburger with no tomato. i for...
# 36  "thomas oreder hamburger with no tomato. i for...
# 37  "thomas oreder hamburger with no tomato. i for...
# 38  "thomas oreder hamburger with no tomato. i for...
# 39  "thomas oreder hamburger with no tomato. i for...
# 40  "thomas oreder hamburger with no tomato. i for...
#
#                          A8 distractor1  ...    distractor3   distractor4  \
# 0   "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 1   "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 2   "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 3   "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 4   "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 5   "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 6   "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 7   "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 8   "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 9   "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 10  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 11  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 12  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 13  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 14  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 15  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 16  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 17  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 18  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 19  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 20  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 21  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 22  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 23  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 24  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 25  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 26  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 27  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 28  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 29  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 30  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 31  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 32  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 33  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 34  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 35  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 36  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 37  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 38  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 39  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
# 40  "none of them like it."    "Return"  ...  "hippocampus"  "brigadeiro"
#
#      distractor5               prolific_id story  p_type  persp  alt_persp  \
# 0   "muffulaeta"  5eb882738aa2327d047dd79b    11       1      1         10
# 1   "muffulaeta"  5eb882738aa2327d047dd79b    11       1      1         10
# 2   "muffulaeta"  5eb882738aa2327d047dd79b    11       1      1         10
# 3   "muffulaeta"  5eb882738aa2327d047dd79b    11       1      1         10
# 4   "muffulaeta"  5eb882738aa2327d047dd79b    11       1      1         10
# 5   "muffulaeta"  5eb882738aa2327d047dd79b    11       1      1         10
# 6   "muffulaeta"  5eb882738aa2327d047dd79b    11       1      1         10
# 7   "muffulaeta"  5eb882738aa2327d047dd79b    11       1      1         10
# 8   "muffulaeta"  5eb882738aa2327d047dd79b    11       1      1         10
# 9   "muffulaeta"  5eb882738aa2327d047dd79b    11       1      1         10
# 10  "muffulaeta"  5eb882738aa2327d047dd79b    11       1      1         10
# 11  "muffulaeta"  5eb882738aa2327d047dd79b    11       1      1         10
# 12  "muffulaeta"  5eb882738aa2327d047dd79b    11       1      1         10
# 13  "muffulaeta"  5eb882738aa2327d047dd79b    11       1      1         10
# 14  "muffulaeta"  5eb882738aa2327d047dd79b    11       1      1         10
# 15  "muffulaeta"  5eb882738aa2327d047dd79b    11       1      1         10
# 16  "muffulaeta"  5eb882738aa2327d047dd79b    11       1      1         10
# 17  "muffulaeta"  5eb882738aa2327d047dd79b    11       1      1         10
# 18  "muffulaeta"  5eb882738aa2327d047dd79b    11       1      1         10
# 19  "muffulaeta"  5eb882738aa2327d047dd79b    11       1      1         10
# 20  "muffulaeta"  5eb882738aa2327d047dd79b    11       1      1         10
#