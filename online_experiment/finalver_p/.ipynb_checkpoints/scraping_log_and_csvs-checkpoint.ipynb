# %%
import re
import codecs
import glob
import csv
import pandas as pd
import numpy as np
import pickle
# %autosave 5
# Out:
# Autosaving every 5 seconds

# %% [markdown]
# # Constructing Standard Data Files for Online Participants
# ##### 5/27/20
# ## I. Treating Log Files
# ### A. Reading in Log Files

# %%
files = glob.glob("*.log")  # the folder with the logs (relative to this file)
# we'll use a regex for this even though they're ugly and painful:
scanQuote = re.compile(r"'(.*?)'")  # finds any number of words within a quote

# %% [markdown]
# ### B. Creating dictionary files_pd with log files data filtered (key: filename .log)

# %%
#instantiate dictionary
files_pd = {}

for filename in files:
    print(filename)
    # open log file
    thisFile = codecs.open( filename, 'r', 'utf-8')
    #initiate a dataframe
    df = pd.DataFrame(columns=['time','keypress'])
    #go through each line in the file
    for line in thisFile.readlines():
        if "DATA" in line:  # new trial reset all entries
            if "Keydown:" in line:
                first, keypress = line.split("Keydown:")
                time = first.split("\t")[0]
                keypress = keypress.strip()
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
            else:
                pass
        if "text_34: autoDraw = false" in line:
            time = "here"
            keypress = 33
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        #recording the distractor words    
        if "text_66: text =" in line:
            time = 'distractor_text'
            b, keypress = line.split("text = ")
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        #mark the end of the distractor typing
        if "instr_9: autoDraw = false" in line:
            time = 44
            keypress = 0
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        #recording the short answer questions
        if "instr: text =" in line:
            b, keypress = line.split("text = ")
            time = 'Q1'
            keypress = keypress.strip()
            if keypress == "\"default text\"":
                pass
            else:
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "instr_2: text =" in line:
            b, keypress = line.split("text = ")
            time = 'Q2'
            keypress = keypress.strip()
            if keypress == "\"default text\"":
                pass
            else:
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "instr_3: text =" in line:
            b, keypress = line.split("text = ")
            time = 'Q3'
            keypress = keypress.strip()
            if keypress == "\"default text\"":
                pass
            else:
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "instr_4: text =" in line:
            b, keypress = line.split("text = ")
            time = 'Q4'
            keypress = keypress.strip()
            if keypress == "\"default text\"":
                pass
            else:
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "instr_5: text =" in line:
            b, keypress = line.split("text = ")
            time = 'Q5'
            keypress = keypress.strip()
            if keypress == "\"default text\"":
                pass
            else:
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "instr_6: text =" in line:
            b, keypress = line.split("text = ")
            time = 'Q6'
            keypress = keypress.strip()
            if keypress == "\"default text\"":
                pass
            else:
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "instr_7: text =" in line:
            b, keypress = line.split("text = ")
            time = 'Q7'
            keypress = keypress.strip()
            if keypress == "\"default text\"":
                pass
            else:
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "instr_8: text =" in line:
            b, keypress = line.split("text = ")
            time = 'Q8'
            keypress = keypress.strip()
            if keypress == "\"default text\"":
                pass
            else:
                df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        #short answers
        text_num = ["43", "44", "45", "46", "47", "48", "51", "53"]
        if "text_43: text = " in line:
            b, keypress = line.split("text = ")
            time = 'A1'
            print('here')
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "text_44: text = " in line:
            b, keypress = line.split("text = ")
            time = 'A2'
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "text_45: text = " in line:
            b, keypress = line.split("text = ")
            time = 'A3'
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "text_46: text = " in line:
            b, keypress = line.split("text = ")
            time = 'A4'
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "text_47: text = " in line:
            b, keypress = line.split("text = ")
            time = 'A5'
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "text_48: text = " in line:
            b, keypress = line.split("text = ")
            time = 'A6'
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "text_51: text = " in line:
            b, keypress = line.split("text = ")
            time = 'A7'
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
        if "text_53: text = " in line:
            b, keypress = line.split("text = ")
            time = 'A8'
            keypress = keypress.strip()
            df = df.append({'time' : time , 'keypress' : keypress} , ignore_index=True)
    #remove rows of pd with empty keypress values
    df = df[df.keypress != '""']
    df = df[df.keypress != '']
    #reset index
    df = df.reset_index(drop=True)
    #add the df to the dictionary
    files_pd[filename] = df
# Out:
# 18_1_online_exp_2020-06-06_14h58.27.858.log
# here

# %%
len(files_pd)
# Out:
# 19

# %% [markdown]
# ## II. Building Standardized Data File
# #### pd w cols = story, type, persp, alt_persp, sa_order, story_presses, distractors, 'SA's
#
# ## A. Instantiate df data_dict (key: filename)

# %%
data_dict = {}

#fill data_dict with all files
for filename in files:
    this_df = pd.DataFrame()
    label = filename[:-4]
    data_dict[label] = this_df

# %% [markdown]
# ### B. Load CSV Files

# %%
#FullForce Behavioral

csvnames = glob.glob('*.csv')

csv_df = {}

for csvname in csvnames:
    print(csvname)
    label = csvname[:-4]
    
    csv_df[label] = pd.read_csv(csvname)
    
print('done!')
# Out:
# PARTICIPANT_1_online_exp_2020-05-06_20h00.18.643.csv
# PARTICIPANT_1_online_exp_2020-05-07_00h46.51.319.csv
# PARTICIPANT_1_online_exp_2020-05-07_23h36.54.796.csv
# PARTICIPANT_1_online_exp_2020-05-07_23h40.02.268.csv
# PARTICIPANT_1_online_exp_2020-05-09_01h01.48.508.csv
# PARTICIPANT_1_online_exp_2020-05-09_01h05.05.369.csv
# PARTICIPANT_1_online_exp_2020-05-09_01h54.27.962.csv
# PARTICIPANT_1_online_exp_2020-05-11_12h52.50.131.csv
# PARTICIPANT_1_online_exp_2020-05-11_20h42.51.597.csv
# PARTICIPANT_1_online_exp_2020-05-11_20h43.08.493.csv
# PARTICIPANT_1_online_exp_2020-05-12_19h57.55.241.csv
# PARTICIPANT_1_online_exp_2020-05-19_15h04.13.258.csv
# PARTICIPANT_1_online_exp_2020-05-19_19h16.09.618.csv
# PARTICIPANT_1_online_exp_2020-05-19_19h17.04.991.csv
# PARTICIPANT_1_online_exp_2020-05-19_19h18.58.644.csv
# PARTICIPANT_1_online_exp_2020-05-20_16h02.59.817.csv
# PARTICIPANT_1_online_exp_2020-05-20_17h03.06.828.csv
# PARTICIPANT_1_online_exp_2020-05-20_22h01.43.581.csv
# PARTICIPANT_1_online_exp_2020-05-20_22h03.41.810.csv
# done!

# %% [markdown]
# ## C. Extract information from files_pd
# ### i. story_presses

# %%
#include if statement, since if the values are in the .csv we will use those, maybe not actually. If this method works
#why not make it ubiquitous for all. I will do some comparisons with people who do have story_presses in their .csv
#to verify this extraction method

for filename in files:
    #call the dataframe for this file
    df = files_pd[filename]
    #finding index of 'here'
    here = np.array(df.index[df['time'] == 'here'].tolist())
    #subtracting 1 to get index of keypresses
    seg = here - 1
    #getting the keypress values
    key_vals = df['keypress'][seg].tolist()
    #turning keypresses into ints
    key_vals = [int(i) for i in key_vals]
    #adjusting the filename to match the key
    label = filename[:-4]
    #adding the key_vals to the df
    data_dict[label]['story_presses'] = key_vals

# %% [markdown]
# ### ii. short answers

# %%
Alist = ['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8']

for filename in files:
    df = files_pd[filename]
    for thisA in Alist:
        #finding index of thisA
        here = np.array(df.index[df['time'] == thisA].tolist())
        #getting the keypress values
        key_vals = df['keypress'][here].tolist()
        if not key_vals:
            this_val = ''
        else:
            #index the last value
            this_val = key_vals[-1]
        label = filename[:-4]
        #adding the key_vals to the df
        data_dict[label][thisA] = this_val

# %%
data_dict[label]
# Out:
#     story_presses                        A1                    A2     A3  \
# 0               9  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 1               1  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 2               9  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 3               1  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 4               1  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 5               1  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 6               1  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 7               1  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 8               1  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 9               1  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 10              1  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 11              1  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 12              1  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 13              9  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 14              9  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 15              1  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 16              9  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 17              1  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 18              1  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 19              1  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 20              1  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 21              1  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 22              1  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 23              1  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 24              1  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 25              1  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 26              9  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 27              1  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 28              1  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 29              1  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 30              1  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 31              9  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 32              9  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 33              1  " 3hours and 35 minutes"  "fault with scanner"  "j35"
# 34              9  " 3hours and 35 minutes"  "fault with scanner"  "j35"
#
#       A4       A5                    A6                     A7    A8
# 0   "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 1   "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 2   "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 3   "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 4   "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 5   "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 6   "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 7   "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 8   "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 9   "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 10  "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 11  "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 12  "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 13  "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 14  "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 15  "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 16  "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 17  "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 18  "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 19  "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 20  "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 21  "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 22  "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 23  "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 24  "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 25  "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 26  "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 27  "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 28  "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 29  "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 30  "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 31  "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 32  "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 33  "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"
# 34  "7d"  "boook"  "were you a gymnast"  "drinks next tuesday"  "11"

# %% [markdown]
# ### iii. distractors

# %%
for filename in files:
    #get the label for the data_dict
    label = filename[:-4]
    #select df from files_pd
    df = files_pd[filename]
    #finding the index of 44, the marker for distractor texts
    here = np.array(df.index[df['time'] == 44].tolist())
    #subtracting 2 to get index of keypresses
    distractors = here - 2
    distractor_vals = df['keypress'][distractors].tolist()
    for i in range(0, 5):
        data_dict[label]['distractor' + str(i+1)] = distractor_vals[i]

# %% [markdown]
# ## D. Extract info from CSV files
# ### i. Get prolific_id, story, type, persp, alt_persp, sa_order

# %%
for filename in files:
    #get the label for the data_dict
    label = filename[:-4]
    #getting prolific id
    data_dict[label]['prolific_id'] = csv_df[label]['Prolific_ID'].iloc[0]
    #getting story number
    data_dict[label]['story'] = int(csv_df[label]['story'].iloc[0])
    #getting priming type
    data_dict[label]['p_type'] = int(csv_df[label]['val2'].iloc[0])
    #perspective
    if "persp_val" in csv_df[label]:
        data_dict[label]['persp'] = int(csv_df[label]['persp_val'].iloc[0])
        #alternative perspective
        data_dict[label]['alt_persp'] = int(csv_df[label]['alt_persp_val'].iloc[0])
    else:
        data_dict[label]['persp'] = int(csv_df[label]['perp_val'].iloc[0])
        #alternative perspective
        data_dict[label]['alt_persp'] = int(csv_df[label]['alt_perp_val'].iloc[0])
    #short answer order
    if "sa_order" in csv_df[label]:
        data_dict[label]['sa_order'] = int(csv_df[label]['sa_order'].iloc[0])
    #if the short answer order is not in the file (pilot i, ii) then put the first sa question in 'sa_order' column    
    else:
        data_dict[label]['sa_order'] = files_pd[filename].loc[files_pd[filename]['time'] == 'Q1', 'keypress'].iloc[0]

# %% [markdown]
# ## E. Recall Data from Qualtrics
# ### i. load CSV from Qualtrics

# %%
q_df = pd.read_csv("qualtrics/qualtrics.csv")

# %% [markdown]
# ### ii. Insert Recall Data from Qualtrics CSV into data_dict using prolific_id

# %%
for key in data_dict.keys():
    #getting prolific id from data_dict
    this_id = data_dict[key]['prolific_id'].iloc[0]
    #index of row with this_id
    data_dict[key]['recall'] = q_df.loc[q_df['Q1'] == this_id, 'Q8'].iloc[0]

# %% [markdown]
# ## F. Pickling

# %%
pickle.dump( data_dict, open( "pickle/data_dict.p", "wb" ) )
